# %% [markdown]
# # Leitura dos arquivos em Verilog, Construção da rede bayseana e Analise dela através da inferencia

# %%
# Importação das bibliotecas
import pyAgrum as gum # pyagrum 
import pyAgrum.lib.notebook as gnb
import matplotlib.pyplot as plt
from pylab import *
from IPython.display import HTML, display
import itertools
import sys 
gum.config['notebook','potential_visible_digits']=2

# %%
# Escrever no arquivo (função traduzida do código do kenner)

def write_to_file(vec_of_vecs, arquivo):
    """
    Escreve uma lista de listas de strings em um arquivo separando os elementos por espaços
    e cada lista interna por uma nova linha

    Parâmetros:
    vec_of_vecs (List[List[str]]): A lista de listas de strings a ser escrita no arquivo
    arquivo (str): O caminho para o arquivo onde os dados serão escritos
    """
    try:
        with open(arquivo, 'w') as out_file:
            for inner_list in vec_of_vecs:
                # Escrever os elementos separados por espaço
                line = ' '.join(inner_list)
                out_file.write(line + '\n')
    except IOError as e:
        print(f"Erro ao abrir ou escrever no arquivo: {arquivo}\n{e}", file=sys.stderr)

# %%
# Função de ler o arquivo em verilog e retornar os elementos em uma estrutura de dados

def read_verilog(caminho_verilog):
    """
    Lê um arquivo Verilog e extrai argumentos lógicos de cada linha que contenha
    um parêntese aberto dentro das primeiras 5 posições

    Parametros:
    caminho_verilog (str): O caminho para o arquivo Verilog a ser lido

    Retorna:
    List[List[str]]: Uma lista de listas contendo os argumentos lógicos extraídos
    """
    data_vet = []
    
    try:
        with open(caminho_verilog, 'r') as arquivo_verilog:
            for line in arquivo_verilog:
                line = line.strip()
                if not line:
                    continue  # Pula linhas vazias

                # Encontrar a posição do primeiro parêntese
                parenthesis_pos = line.find('(')
                if parenthesis_pos != -1 and parenthesis_pos < 5:
                    # Extrair o argumento lógico antes do parêntese
                    logic_argument = line[:parenthesis_pos].strip()
                    temp_vector = [logic_argument]

                    # Extrair o conteúdo dentro dos parênteses
                    inside_parentheses = line[parenthesis_pos+1:]
                    # Remover tudo após o último parêntese
                    end_parenthesis_pos = inside_parentheses.find(')')
                    if end_parenthesis_pos != -1:
                        arguments_str = inside_parentheses[:end_parenthesis_pos]
                        # Dividir os argumentos por vírgula
                        arguments = [arg.strip() for arg in arguments_str.split(',')]
                        temp_vector.extend(arguments)
                    
                    data_vet.append(temp_vector)
    except IOError as e:
        print(f"Erro ao abrir o arquivo: {caminho_verilog}\n{e}", file=sys.stderr)
        return []

    return data_vet

# %%
# Construção do código de ler o txt do verilog e criar a rede bayseana
# 1° Parte: estudo de como ira retornar o txt 
with open('verilog/C1355.txt', 'r') as f:

    for linha in f: 
        linha = linha.strip()
        if not linha:
            continue 

        partes = linha.split()
        operacao = partes[0] # porta lógica
        saida = partes[1] # output
        entradas = partes[2:] # input
        print(f'\nPartes: {partes}\nOperações: {partes[0]}\nSaida: {partes[1]}')
        if operacao == 'or' or operacao == 'and':
            print(f'\nEntradas 1: {entradas[0]}\nEntradas 2: {entradas[1]}')
        else:
            print(f'\nEntrada: {entradas[0]}')
# Out:
# Partes: ['and', 'v1', 'n0', 'o0']
# Operações: and
# Saida: v1
#
# Entradas 1: n0
# Entradas 2: o0
#
# Partes: ['and', 'w1', 'm0', 'o0']
# Operações: and
# Saida: w1
#
# Entradas 1: m0
# Entradas 2: o0
#
# Partes: ['and', 'x1', 'l0', 'o0']
# Operações: and
# Saida: x1
#
# Entradas 1: l0
# Entradas 2: o0
#
# Partes: ['and', 'y1', 'k0', 'o0']
# Operações: and
# Saida: y1
#
# Entradas 1: k0
# Entradas 2: o0
#
# Partes: ['and', 'z1', 'j0', 'o0']
# Operações: and
# Saida: z1
#
# Entradas 1: j0
# Entradas 2: o0
#
# Partes: ['and', 'a2', 'i0', 'o0']
# Operações: and
# Saida: a2
#
# Entradas 1: i0
# Entradas 2: o0
#
# Partes: ['and', 'b2', 'h0', 'o0']
# Operações: and
# Saida: b2
#
# Entradas 1: h0
# Entradas 2: o0
#
# Partes: ['and', 'c2', 'g0', 'o0']
# Operações: and
# Saida: c2
#
# Entradas 1: g0
# Entradas 2: o0
#
# Partes: ['not', 't_0', 'f0']
# Operações: not
# Saida: t_0
#
# Entrada: f0
#
# Partes: ['not', 't_1', 'e0']
# Operações: not
# Saida: t_1
#
# Entrada: e0
#
# Partes: ['or', 'd2', 't_0', 't_1']
# Operações: or
# Saida: d2
#
# Entradas 1: t_0
# Entradas 2: t_1
#
# Partes: ['not', 't_2', 'd0']
# Operações: not
# Saida: t_2
#
# Entrada: d0
#
# Partes: ['not', 't_3', 'c0']
# Operações: not
# Saida: t_3
#
# Entrada: c0
#
# Partes: ['or', 'e2', 't_2', 't_3']
# Operações: or
# Saida: e2
#
# Entradas 1: t_2
# Entradas 2: t_3
#
# Partes: ['not', 't_4', 'f0']
# Operações: not
# Saida: t_4
#
# Entrada: f0
#
# Partes: ['not', 't_5', 'b0']
# Operações: not
# Saida: t_5
#
# Entrada: b0
#
# Partes: ['or', 'f2', 't_4', 't_5']
# Operações: or
# Saida: f2
#
# Entradas 1: t_4
# Entradas 2: t_5
#
# Partes: ['not', 't_6', 'e0']
# Operações: not
# Saida: t_6
#
# Entrada: e0
#
# Partes: ['not', 't_7', 'a0']
# Operações: not
# Saida: t_7
#
# Entrada: a0
#
# Partes: ['or', 'g2', 't_6', 't_7']
# Operações: or
# Saida: g2
#
# Entradas 1: t_6
# Entradas 2: t_7
#
# Partes: ['not', 't_8', 'b0']
# Operações: not
# Saida: t_8
#
# Entrada: b0
#
# Partes: ['not', 't_9', 'a0']
# Operações: not
# Saida: t_9
#
# Entrada: a0
#
# Partes: ['or', 'h2', 't_8', 't_9']
# Operações: or
# Saida: h2
#
# Entradas 1: t_8
# Entradas 2: t_9
#
# Partes: ['not', 't_10', 'd0']
# Operações: not
# Saida: t_10
#
# Entrada: d0
#
# Partes: ['not', 't_11', 'z']
# Operações: not
# Saida: t_11
#
# Entrada: z
#
# Partes: ['or', 'i2', 't_10', 't_11']
# Operações: or
# Saida: i2
#
# Entradas 1: t_10
# Entradas 2: t_11
#
# Partes: ['not', 't_12', 'c0']
# Operações: not
# Saida: t_12
#
# Entrada: c0
#
# Partes: ['not', 't_13', 'y']
# Operações: not
# Saida: t_13
#
# Entrada: y
#
# Partes: ['or', 'j2', 't_12', 't_13']
# Operações: or
# Saida: j2
#
# Entradas 1: t_12
# Entradas 2: t_13
#
# Partes: ['not', 't_14', 'z']
# Operações: not
# Saida: t_14
#
# Entrada: z
#
# Partes: ['not', 't_15', 'y']
# Operações: not
# Saida: t_15
#
# Entrada: y
#
# Partes: ['or', 'k2', 't_14', 't_15']
# Operações: or
# Saida: k2
#
# Entradas 1: t_14
# Entradas 2: t_15
#
# Partes: ['not', 't_16', 'x']
# Operações: not
# Saida: t_16
#
# Entrada: x
#
# Partes: ['not', 't_17', 'w']
# Operações: not
# Saida: t_17
#
# Entrada: w
#
# Partes: ['or', 'l2', 't_16', 't_17']
# Operações: or
# Saida: l2
#
# Entradas 1: t_16
# Entradas 2: t_17
#
# Partes: ['not', 't_18', 'v']
# Operações: not
# Saida: t_18
#
# Entrada: v
#
# Partes: ['not', 't_19', 'u']
# Operações: not
# Saida: t_19
#
# Entrada: u
#
# Partes: ['or', 'm2', 't_18', 't_19']
# Operações: or
# Saida: m2
#
# Entradas 1: t_18
# Entradas 2: t_19
#
# Partes: ['not', 't_20', 'x']
# Operações: not
# Saida: t_20
#
# Entrada: x
#
# Partes: ['not', 't_21', 't']
# Operações: not
# Saida: t_21
#
# Entrada: t
#
# Partes: ['or', 'n2', 't_20', 't_21']
# Operações: or
# Saida: n2
#
# Entradas 1: t_20
# Entradas 2: t_21
#
# Partes: ['not', 't_22', 'w']
# Operações: not
# Saida: t_22
#
# Entrada: w
#
# Partes: ['not', 't_23', 's']
# Operações: not
# Saida: t_23
#
# Entrada: s
#
# Partes: ['or', 'o2', 't_22', 't_23']
# Operações: or
# Saida: o2
#
# Entradas 1: t_22
# Entradas 2: t_23
#
# Partes: ['not', 't_24', 't']
# Operações: not
# Saida: t_24
#
# Entrada: t
#
# Partes: ['not', 't_25', 's']
# Operações: not
# Saida: t_25
#
# Entrada: s
#
# Partes: ['or', 'p2', 't_24', 't_25']
# Operações: or
# Saida: p2
#
# Entradas 1: t_24
# Entradas 2: t_25
#
# Partes: ['not', 't_26', 'v']
# Operações: not
# Saida: t_26
#
# Entrada: v
#
# Partes: ['not', 't_27', 'r']
# Operações: not
# Saida: t_27
#
# Entrada: r
#
# Partes: ['or', 'q2', 't_26', 't_27']
# Operações: or
# Saida: q2
#
# Entradas 1: t_26
# Entradas 2: t_27
#
# Partes: ['not', 't_28', 'u']
# Operações: not
# Saida: t_28
#
# Entrada: u
#
# Partes: ['not', 't_29', 'q']
# Operações: not
# Saida: t_29
#
# Entrada: q
#
# Partes: ['or', 'r2', 't_28', 't_29']
# Operações: or
# Saida: r2
#
# Entradas 1: t_28
# Entradas 2: t_29
#
# Partes: ['not', 't_30', 'r']
# Operações: not
# Saida: t_30
#
# Entrada: r
#
# Partes: ['not', 't_31', 'q']
# Operações: not
# Saida: t_31
#
# Entrada: q
#
# Partes: ['or', 's2', 't_30', 't_31']
# Operações: or
# Saida: s2
#
# Entradas 1: t_30
# Entradas 2: t_31
#
# Partes: ['not', 't_32', 'p']
# Operações: not
# Saida: t_32
#
# Entrada: p
#
# Partes: ['not', 't_33', 'o']
# Operações: not
# Saida: t_33
#
# Entrada: o
#
# Partes: ['or', 't2', 't_32', 't_33']
# Operações: or
# Saida: t2
#
# Entradas 1: t_32
# Entradas 2: t_33
#
# Partes: ['not', 't_34', 'n']
# Operações: not
# Saida: t_34
#
# Entrada: n
#
# Partes: ['not', 't_35', 'm']
# Operações: not
# Saida: t_35
#
# Entrada: m
#
# Partes: ['or', 'u2', 't_34', 't_35']
# Operações: or
# Saida: u2
#
# Entradas 1: t_34
# Entradas 2: t_35
#
# Partes: ['not', 't_36', 'p']
# Operações: not
# Saida: t_36
#
# Entrada: p
#
# Partes: ['not', 't_37', 'l']
# Operações: not
# Saida: t_37
#
# Entrada: l
#
# Partes: ['or', 'v2', 't_36', 't_37']
# Operações: or
# Saida: v2
#
# Entradas 1: t_36
# Entradas 2: t_37
#
# Partes: ['not', 't_38', 'o']
# Operações: not
# Saida: t_38
#
# Entrada: o
#
# Partes: ['not', 't_39', 'k']
# Operações: not
# Saida: t_39
#
# Entrada: k
#
# Partes: ['or', 'w2', 't_38', 't_39']
# Operações: or
# Saida: w2
#
# Entradas 1: t_38
# Entradas 2: t_39
#
# Partes: ['not', 't_40', 'l']
# Operações: not
# Saida: t_40
#
# Entrada: l
#
# Partes: ['not', 't_41', 'k']
# Operações: not
# Saida: t_41
#
# Entrada: k
#
# Partes: ['or', 'x2', 't_40', 't_41']
# Operações: or
# Saida: x2
#
# Entradas 1: t_40
# Entradas 2: t_41
#
# Partes: ['not', 't_42', 'n']
# Operações: not
# Saida: t_42
#
# Entrada: n
#
# Partes: ['not', 't_43', 'j']
# Operações: not
# Saida: t_43
#
# Entrada: j
#
# Partes: ['or', 'y2', 't_42', 't_43']
# Operações: or
# Saida: y2
#
# Entradas 1: t_42
# Entradas 2: t_43
#
# Partes: ['not', 't_44', 'm']
# Operações: not
# Saida: t_44
#
# Entrada: m
#
# Partes: ['not', 't_45', 'i']
# Operações: not
# Saida: t_45
#
# Entrada: i
#
# Partes: ['or', 'z2', 't_44', 't_45']
# Operações: or
# Saida: z2
#
# Entradas 1: t_44
# Entradas 2: t_45
#
# Partes: ['not', 't_46', 'j']
# Operações: not
# Saida: t_46
#
# Entrada: j
#
# Partes: ['not', 't_47', 'i']
# Operações: not
# Saida: t_47
#
# Entrada: i
#
# Partes: ['or', 'a3', 't_46', 't_47']
# Operações: or
# Saida: a3
#
# Entradas 1: t_46
# Entradas 2: t_47
#
# Partes: ['not', 't_48', 'h']
# Operações: not
# Saida: t_48
#
# Entrada: h
#
# Partes: ['not', 't_49', 'g']
# Operações: not
# Saida: t_49
#
# Entrada: g
#
# Partes: ['or', 'b3', 't_48', 't_49']
# Operações: or
# Saida: b3
#
# Entradas 1: t_48
# Entradas 2: t_49
#
# Partes: ['not', 't_50', 'f']
# Operações: not
# Saida: t_50
#
# Entrada: f
#
# Partes: ['not', 't_51', 'e']
# Operações: not
# Saida: t_51
#
# Entrada: e
#
# Partes: ['or', 'c3', 't_50', 't_51']
# Operações: or
# Saida: c3
#
# Entradas 1: t_50
# Entradas 2: t_51
#
# Partes: ['not', 't_52', 'h']
# Operações: not
# Saida: t_52
#
# Entrada: h
#
# Partes: ['not', 't_53', 'd']
# Operações: not
# Saida: t_53
#
# Entrada: d
#
# Partes: ['or', 'd3', 't_52', 't_53']
# Operações: or
# Saida: d3
#
# Entradas 1: t_52
# Entradas 2: t_53
#
# Partes: ['not', 't_54', 'g']
# Operações: not
# Saida: t_54
#
# Entrada: g
#
# Partes: ['not', 't_55', 'c']
# Operações: not
# Saida: t_55
#
# Entrada: c
#
# Partes: ['or', 'e3', 't_54', 't_55']
# Operações: or
# Saida: e3
#
# Entradas 1: t_54
# Entradas 2: t_55
#
# Partes: ['not', 't_56', 'd']
# Operações: not
# Saida: t_56
#
# Entrada: d
#
# Partes: ['not', 't_57', 'c']
# Operações: not
# Saida: t_57
#
# Entrada: c
#
# Partes: ['or', 'f3', 't_56', 't_57']
# Operações: or
# Saida: f3
#
# Entradas 1: t_56
# Entradas 2: t_57
#
# Partes: ['not', 't_58', 'f']
# Operações: not
# Saida: t_58
#
# Entrada: f
#
# Partes: ['not', 't_59', 'b']
# Operações: not
# Saida: t_59
#
# Entrada: b
#
# Partes: ['or', 'g3', 't_58', 't_59']
# Operações: or
# Saida: g3
#
# Entradas 1: t_58
# Entradas 2: t_59
#
# Partes: ['not', 't_60', 'e']
# Operações: not
# Saida: t_60
#
# Entrada: e
#
# Partes: ['not', 't_61', 'a']
# Operações: not
# Saida: t_61
#
# Entrada: a
#
# Partes: ['or', 'h3', 't_60', 't_61']
# Operações: or
# Saida: h3
#
# Entradas 1: t_60
# Entradas 2: t_61
#
# Partes: ['not', 't_62', 'b']
# Operações: not
# Saida: t_62
#
# Entrada: b
#
# Partes: ['not', 't_63', 'a']
# Operações: not
# Saida: t_63
#
# Entrada: a
#
# Partes: ['or', 'i3', 't_62', 't_63']
# Operações: or
# Saida: i3
#
# Entradas 1: t_62
# Entradas 2: t_63
#
# Partes: ['not', 't_64', 'f2']
# Operações: not
# Saida: t_64
#
# Entrada: f2
#
# Partes: ['not', 't_65', 'f0']
# Operações: not
# Saida: t_65
#
# Entrada: f0
#
# Partes: ['or', 'j3', 't_64', 't_65']
# Operações: or
# Saida: j3
#
# Entradas 1: t_64
# Entradas 2: t_65
#
# Partes: ['not', 't_66', 'd2']
# Operações: not
# Saida: t_66
#
# Entrada: d2
#
# Partes: ['not', 't_67', 'f0']
# Operações: not
# Saida: t_67
#
# Entrada: f0
#
# Partes: ['or', 'k3', 't_66', 't_67']
# Operações: or
# Saida: k3
#
# Entradas 1: t_66
# Entradas 2: t_67
#
# Partes: ['not', 't_68', 'g2']
# Operações: not
# Saida: t_68
#
# Entrada: g2
#
# Partes: ['not', 't_69', 'e0']
# Operações: not
# Saida: t_69
#
# Entrada: e0
#
# Partes: ['or', 'l3', 't_68', 't_69']
# Operações: or
# Saida: l3
#
# Entradas 1: t_68
# Entradas 2: t_69
#
# Partes: ['not', 't_70', 'd2']
# Operações: not
# Saida: t_70
#
# Entrada: d2
#
# Partes: ['not', 't_71', 'e0']
# Operações: not
# Saida: t_71
#
# Entrada: e0
#
# Partes: ['or', 'm3', 't_70', 't_71']
# Operações: or
# Saida: m3
#
# Entradas 1: t_70
# Entradas 2: t_71
#
# Partes: ['not', 't_72', 'i2']
# Operações: not
# Saida: t_72
#
# Entrada: i2
#
# Partes: ['not', 't_73', 'd0']
# Operações: not
# Saida: t_73
#
# Entrada: d0
#
# Partes: ['or', 'n3', 't_72', 't_73']
# Operações: or
# Saida: n3
#
# Entradas 1: t_72
# Entradas 2: t_73
#
# Partes: ['not', 't_74', 'e2']
# Operações: not
# Saida: t_74
#
# Entrada: e2
#
# Partes: ['not', 't_75', 'd0']
# Operações: not
# Saida: t_75
#
# Entrada: d0
#
# Partes: ['or', 'o3', 't_74', 't_75']
# Operações: or
# Saida: o3
#
# Entradas 1: t_74
# Entradas 2: t_75
#
# Partes: ['not', 't_76', 'j2']
# Operações: not
# Saida: t_76
#
# Entrada: j2
#
# Partes: ['not', 't_77', 'c0']
# Operações: not
# Saida: t_77
#
# Entrada: c0
#
# Partes: ['or', 'p3', 't_76', 't_77']
# Operações: or
# Saida: p3
#
# Entradas 1: t_76
# Entradas 2: t_77
#
# Partes: ['not', 't_78', 'e2']
# Operações: not
# Saida: t_78
#
# Entrada: e2
#
# Partes: ['not', 't_79', 'c0']
# Operações: not
# Saida: t_79
#
# Entrada: c0
#
# Partes: ['or', 'q3', 't_78', 't_79']
# Operações: or
# Saida: q3
#
# Entradas 1: t_78
# Entradas 2: t_79
#
# Partes: ['not', 't_80', 'f2']
# Operações: not
# Saida: t_80
#
# Entrada: f2
#
# Partes: ['not', 't_81', 'b0']
# Operações: not
# Saida: t_81
#
# Entrada: b0
#
# Partes: ['or', 'r3', 't_80', 't_81']
# Operações: or
# Saida: r3
#
# Entradas 1: t_80
# Entradas 2: t_81
#
# Partes: ['not', 't_82', 'h2']
# Operações: not
# Saida: t_82
#
# Entrada: h2
#
# Partes: ['not', 't_83', 'b0']
# Operações: not
# Saida: t_83
#
# Entrada: b0
#
# Partes: ['or', 's3', 't_82', 't_83']
# Operações: or
# Saida: s3
#
# Entradas 1: t_82
# Entradas 2: t_83
#
# Partes: ['not', 't_84', 'g2']
# Operações: not
# Saida: t_84
#
# Entrada: g2
#
# Partes: ['not', 't_85', 'a0']
# Operações: not
# Saida: t_85
#
# Entrada: a0
#
# Partes: ['or', 't3', 't_84', 't_85']
# Operações: or
# Saida: t3
#
# Entradas 1: t_84
# Entradas 2: t_85
#
# Partes: ['not', 't_86', 'h2']
# Operações: not
# Saida: t_86
#
# Entrada: h2
#
# Partes: ['not', 't_87', 'a0']
# Operações: not
# Saida: t_87
#
# Entrada: a0
#
# Partes: ['or', 'u3', 't_86', 't_87']
# Operações: or
# Saida: u3
#
# Entradas 1: t_86
# Entradas 2: t_87
#
# Partes: ['not', 't_88', 'i2']
# Operações: not
# Saida: t_88
#
# Entrada: i2
#
# Partes: ['not', 't_89', 'z']
# Operações: not
# Saida: t_89
#
# Entrada: z
#
# Partes: ['or', 'v3', 't_88', 't_89']
# Operações: or
# Saida: v3
#
# Entradas 1: t_88
# Entradas 2: t_89
#
# Partes: ['not', 't_90', 'k2']
# Operações: not
# Saida: t_90
#
# Entrada: k2
#
# Partes: ['not', 't_91', 'z']
# Operações: not
# Saida: t_91
#
# Entrada: z
#
# Partes: ['or', 'w3', 't_90', 't_91']
# Operações: or
# Saida: w3
#
# Entradas 1: t_90
# Entradas 2: t_91
#
# Partes: ['not', 't_92', 'j2']
# Operações: not
# Saida: t_92
#
# Entrada: j2
#
# Partes: ['not', 't_93', 'y']
# Operações: not
# Saida: t_93
#
# Entrada: y
#
# Partes: ['or', 'x3', 't_92', 't_93']
# Operações: or
# Saida: x3
#
# Entradas 1: t_92
# Entradas 2: t_93
#
# Partes: ['not', 't_94', 'k2']
# Operações: not
# Saida: t_94
#
# Entrada: k2
#
# Partes: ['not', 't_95', 'y']
# Operações: not
# Saida: t_95
#
# Entrada: y
#
# Partes: ['or', 'y3', 't_94', 't_95']
# Operações: or
# Saida: y3
#
# Entradas 1: t_94
# Entradas 2: t_95
#
# Partes: ['not', 't_96', 'n2']
# Operações: not
# Saida: t_96
#
# Entrada: n2
#
# Partes: ['not', 't_97', 'x']
# Operações: not
# Saida: t_97
#
# Entrada: x
#
# Partes: ['or', 'z3', 't_96', 't_97']
# Operações: or
# Saida: z3
#
# Entradas 1: t_96
# Entradas 2: t_97
#
# Partes: ['not', 't_98', 'l2']
# Operações: not
# Saida: t_98
#
# Entrada: l2
#
# Partes: ['not', 't_99', 'x']
# Operações: not
# Saida: t_99
#
# Entrada: x
#
# Partes: ['or', 'a4', 't_98', 't_99']
# Operações: or
# Saida: a4
#
# Entradas 1: t_98
# Entradas 2: t_99
#
# Partes: ['not', 't_100', 'o2']
# Operações: not
# Saida: t_100
#
# Entrada: o2
#
# Partes: ['not', 't_101', 'w']
# Operações: not
# Saida: t_101
#
# Entrada: w
#
# Partes: ['or', 'b4', 't_100', 't_101']
# Operações: or
# Saida: b4
#
# Entradas 1: t_100
# Entradas 2: t_101
#
# Partes: ['not', 't_102', 'l2']
# Operações: not
# Saida: t_102
#
# Entrada: l2
#
# Partes: ['not', 't_103', 'w']
# Operações: not
# Saida: t_103
#
# Entrada: w
#
# Partes: ['or', 'c4', 't_102', 't_103']
# Operações: or
# Saida: c4
#
# Entradas 1: t_102
# Entradas 2: t_103
#
# Partes: ['not', 't_104', 'q2']
# Operações: not
# Saida: t_104
#
# Entrada: q2
#
# Partes: ['not', 't_105', 'v']
# Operações: not
# Saida: t_105
#
# Entrada: v
#
# Partes: ['or', 'd4', 't_104', 't_105']
# Operações: or
# Saida: d4
#
# Entradas 1: t_104
# Entradas 2: t_105
#
# Partes: ['not', 't_106', 'm2']
# Operações: not
# Saida: t_106
#
# Entrada: m2
#
# Partes: ['not', 't_107', 'v']
# Operações: not
# Saida: t_107
#
# Entrada: v
#
# Partes: ['or', 'e4', 't_106', 't_107']
# Operações: or
# Saida: e4
#
# Entradas 1: t_106
# Entradas 2: t_107
#
# Partes: ['not', 't_108', 'r2']
# Operações: not
# Saida: t_108
#
# Entrada: r2
#
# Partes: ['not', 't_109', 'u']
# Operações: not
# Saida: t_109
#
# Entrada: u
#
# Partes: ['or', 'f4', 't_108', 't_109']
# Operações: or
# Saida: f4
#
# Entradas 1: t_108
# Entradas 2: t_109
#
# Partes: ['not', 't_110', 'm2']
# Operações: not
# Saida: t_110
#
# Entrada: m2
#
# Partes: ['not', 't_111', 'u']
# Operações: not
# Saida: t_111
#
# Entrada: u
#
# Partes: ['or', 'g4', 't_110', 't_111']
# Operações: or
# Saida: g4
#
# Entradas 1: t_110
# Entradas 2: t_111
#
# Partes: ['not', 't_112', 'n2']
# Operações: not
# Saida: t_112
#
# Entrada: n2
#
# Partes: ['not', 't_113', 't']
# Operações: not
# Saida: t_113
#
# Entrada: t
#
# Partes: ['or', 'h4', 't_112', 't_113']
# Operações: or
# Saida: h4
#
# Entradas 1: t_112
# Entradas 2: t_113
#
# Partes: ['not', 't_114', 'p2']
# Operações: not
# Saida: t_114
#
# Entrada: p2
#
# Partes: ['not', 't_115', 't']
# Operações: not
# Saida: t_115
#
# Entrada: t
#
# Partes: ['or', 'i4', 't_114', 't_115']
# Operações: or
# Saida: i4
#
# Entradas 1: t_114
# Entradas 2: t_115
#
# Partes: ['not', 't_116', 'o2']
# Operações: not
# Saida: t_116
#
# Entrada: o2
#
# Partes: ['not', 't_117', 's']
# Operações: not
# Saida: t_117
#
# Entrada: s
#
# Partes: ['or', 'j4', 't_116', 't_117']
# Operações: or
# Saida: j4
#
# Entradas 1: t_116
# Entradas 2: t_117
#
# Partes: ['not', 't_118', 'p2']
# Operações: not
# Saida: t_118
#
# Entrada: p2
#
# Partes: ['not', 't_119', 's']
# Operações: not
# Saida: t_119
#
# Entrada: s
#
# Partes: ['or', 'k4', 't_118', 't_119']
# Operações: or
# Saida: k4
#
# Entradas 1: t_118
# Entradas 2: t_119
#
# Partes: ['not', 't_120', 'q2']
# Operações: not
# Saida: t_120
#
# Entrada: q2
#
# Partes: ['not', 't_121', 'r']
# Operações: not
# Saida: t_121
#
# Entrada: r
#
# Partes: ['or', 'l4', 't_120', 't_121']
# Operações: or
# Saida: l4
#
# Entradas 1: t_120
# Entradas 2: t_121
#
# Partes: ['not', 't_122', 's2']
# Operações: not
# Saida: t_122
#
# Entrada: s2
#
# Partes: ['not', 't_123', 'r']
# Operações: not
# Saida: t_123
#
# Entrada: r
#
# Partes: ['or', 'm4', 't_122', 't_123']
# Operações: or
# Saida: m4
#
# Entradas 1: t_122
# Entradas 2: t_123
#
# Partes: ['not', 't_124', 'r2']
# Operações: not
# Saida: t_124
#
# Entrada: r2
#
# Partes: ['not', 't_125', 'q']
# Operações: not
# Saida: t_125
#
# Entrada: q
#
# Partes: ['or', 'n4', 't_124', 't_125']
# Operações: or
# Saida: n4
#
# Entradas 1: t_124
# Entradas 2: t_125
#
# Partes: ['not', 't_126', 's2']
# Operações: not
# Saida: t_126
#
# Entrada: s2
#
# Partes: ['not', 't_127', 'q']
# Operações: not
# Saida: t_127
#
# Entrada: q
#
# Partes: ['or', 'o4', 't_126', 't_127']
# Operações: or
# Saida: o4
#
# Entradas 1: t_126
# Entradas 2: t_127
#
# Partes: ['not', 't_128', 'v2']
# Operações: not
# Saida: t_128
#
# Entrada: v2
#
# Partes: ['not', 't_129', 'p']
# Operações: not
# Saida: t_129
#
# Entrada: p
#
# Partes: ['or', 'p4', 't_128', 't_129']
# Operações: or
# Saida: p4
#
# Entradas 1: t_128
# Entradas 2: t_129
#
# Partes: ['not', 't_130', 't2']
# Operações: not
# Saida: t_130
#
# Entrada: t2
#
# Partes: ['not', 't_131', 'p']
# Operações: not
# Saida: t_131
#
# Entrada: p
#
# Partes: ['or', 'q4', 't_130', 't_131']
# Operações: or
# Saida: q4
#
# Entradas 1: t_130
# Entradas 2: t_131
#
# Partes: ['not', 't_132', 'w2']
# Operações: not
# Saida: t_132
#
# Entrada: w2
#
# Partes: ['not', 't_133', 'o']
# Operações: not
# Saida: t_133
#
# Entrada: o
#
# Partes: ['or', 'r4', 't_132', 't_133']
# Operações: or
# Saida: r4
#
# Entradas 1: t_132
# Entradas 2: t_133
#
# Partes: ['not', 't_134', 't2']
# Operações: not
# Saida: t_134
#
# Entrada: t2
#
# Partes: ['not', 't_135', 'o']
# Operações: not
# Saida: t_135
#
# Entrada: o
#
# Partes: ['or', 's4', 't_134', 't_135']
# Operações: or
# Saida: s4
#
# Entradas 1: t_134
# Entradas 2: t_135
#
# Partes: ['not', 't_136', 'y2']
# Operações: not
# Saida: t_136
#
# Entrada: y2
#
# Partes: ['not', 't_137', 'n']
# Operações: not
# Saida: t_137
#
# Entrada: n
#
# Partes: ['or', 't4', 't_136', 't_137']
# Operações: or
# Saida: t4
#
# Entradas 1: t_136
# Entradas 2: t_137
#
# Partes: ['not', 't_138', 'u2']
# Operações: not
# Saida: t_138
#
# Entrada: u2
#
# Partes: ['not', 't_139', 'n']
# Operações: not
# Saida: t_139
#
# Entrada: n
#
# Partes: ['or', 'u4', 't_138', 't_139']
# Operações: or
# Saida: u4
#
# Entradas 1: t_138
# Entradas 2: t_139
#
# Partes: ['not', 't_140', 'z2']
# Operações: not
# Saida: t_140
#
# Entrada: z2
#
# Partes: ['not', 't_141', 'm']
# Operações: not
# Saida: t_141
#
# Entrada: m
#
# Partes: ['or', 'v4', 't_140', 't_141']
# Operações: or
# Saida: v4
#
# Entradas 1: t_140
# Entradas 2: t_141
#
# Partes: ['not', 't_142', 'u2']
# Operações: not
# Saida: t_142
#
# Entrada: u2
#
# Partes: ['not', 't_143', 'm']
# Operações: not
# Saida: t_143
#
# Entrada: m
#
# Partes: ['or', 'w4', 't_142', 't_143']
# Operações: or
# Saida: w4
#
# Entradas 1: t_142
# Entradas 2: t_143
#
# Partes: ['not', 't_144', 'v2']
# Operações: not
# Saida: t_144
#
# Entrada: v2
#
# Partes: ['not', 't_145', 'l']
# Operações: not
# Saida: t_145
#
# Entrada: l
#
# Partes: ['or', 'x4', 't_144', 't_145']
# Operações: or
# Saida: x4
#
# Entradas 1: t_144
# Entradas 2: t_145
#
# Partes: ['not', 't_146', 'x2']
# Operações: not
# Saida: t_146
#
# Entrada: x2
#
# Partes: ['not', 't_147', 'l']
# Operações: not
# Saida: t_147
#
# Entrada: l
#
# Partes: ['or', 'y4', 't_146', 't_147']
# Operações: or
# Saida: y4
#
# Entradas 1: t_146
# Entradas 2: t_147
#
# Partes: ['not', 't_148', 'w2']
# Operações: not
# Saida: t_148
#
# Entrada: w2
#
# Partes: ['not', 't_149', 'k']
# Operações: not
# Saida: t_149
#
# Entrada: k
#
# Partes: ['or', 'z4', 't_148', 't_149']
# Operações: or
# Saida: z4
#
# Entradas 1: t_148
# Entradas 2: t_149
#
# Partes: ['not', 't_150', 'x2']
# Operações: not
# Saida: t_150
#
# Entrada: x2
#
# Partes: ['not', 't_151', 'k']
# Operações: not
# Saida: t_151
#
# Entrada: k
#
# Partes: ['or', 'a5', 't_150', 't_151']
# Operações: or
# Saida: a5
#
# Entradas 1: t_150
# Entradas 2: t_151
#
# Partes: ['not', 't_152', 'y2']
# Operações: not
# Saida: t_152
#
# Entrada: y2
#
# Partes: ['not', 't_153', 'j']
# Operações: not
# Saida: t_153
#
# Entrada: j
#
# Partes: ['or', 'b5', 't_152', 't_153']
# Operações: or
# Saida: b5
#
# Entradas 1: t_152
# Entradas 2: t_153
#
# Partes: ['not', 't_154', 'a3']
# Operações: not
# Saida: t_154
#
# Entrada: a3
#
# Partes: ['not', 't_155', 'j']
# Operações: not
# Saida: t_155
#
# Entrada: j
#
# Partes: ['or', 'c5', 't_154', 't_155']
# Operações: or
# Saida: c5
#
# Entradas 1: t_154
# Entradas 2: t_155
#
# Partes: ['not', 't_156', 'z2']
# Operações: not
# Saida: t_156
#
# Entrada: z2
#
# Partes: ['not', 't_157', 'i']
# Operações: not
# Saida: t_157
#
# Entrada: i
#
# Partes: ['or', 'd5', 't_156', 't_157']
# Operações: or
# Saida: d5
#
# Entradas 1: t_156
# Entradas 2: t_157
#
# Partes: ['not', 't_158', 'a3']
# Operações: not
# Saida: t_158
#
# Entrada: a3
#
# Partes: ['not', 't_159', 'i']
# Operações: not
# Saida: t_159
#
# Entrada: i
#
# Partes: ['or', 'e5', 't_158', 't_159']
# Operações: or
# Saida: e5
#
# Entradas 1: t_158
# Entradas 2: t_159
#
# Partes: ['not', 't_160', 'd3']
# Operações: not
# Saida: t_160
#
# Entrada: d3
#
# Partes: ['not', 't_161', 'h']
# Operações: not
# Saida: t_161
#
# Entrada: h
#
# Partes: ['or', 'f5', 't_160', 't_161']
# Operações: or
# Saida: f5
#
# Entradas 1: t_160
# Entradas 2: t_161
#
# Partes: ['not', 't_162', 'b3']
# Operações: not
# Saida: t_162
#
# Entrada: b3
#
# Partes: ['not', 't_163', 'h']
# Operações: not
# Saida: t_163
#
# Entrada: h
#
# Partes: ['or', 'g5', 't_162', 't_163']
# Operações: or
# Saida: g5
#
# Entradas 1: t_162
# Entradas 2: t_163
#
# Partes: ['not', 't_164', 'e3']
# Operações: not
# Saida: t_164
#
# Entrada: e3
#
# Partes: ['not', 't_165', 'g']
# Operações: not
# Saida: t_165
#
# Entrada: g
#
# Partes: ['or', 'h5', 't_164', 't_165']
# Operações: or
# Saida: h5
#
# Entradas 1: t_164
# Entradas 2: t_165
#
# Partes: ['not', 't_166', 'b3']
# Operações: not
# Saida: t_166
#
# Entrada: b3
#
# Partes: ['not', 't_167', 'g']
# Operações: not
# Saida: t_167
#
# Entrada: g
#
# Partes: ['or', 'i5', 't_166', 't_167']
# Operações: or
# Saida: i5
#
# Entradas 1: t_166
# Entradas 2: t_167
#
# Partes: ['not', 't_168', 'g3']
# Operações: not
# Saida: t_168
#
# Entrada: g3
#
# Partes: ['not', 't_169', 'f']
# Operações: not
# Saida: t_169
#
# Entrada: f
#
# Partes: ['or', 'j5', 't_168', 't_169']
# Operações: or
# Saida: j5
#
# Entradas 1: t_168
# Entradas 2: t_169
#
# Partes: ['not', 't_170', 'c3']
# Operações: not
# Saida: t_170
#
# Entrada: c3
#
# Partes: ['not', 't_171', 'f']
# Operações: not
# Saida: t_171
#
# Entrada: f
#
# Partes: ['or', 'k5', 't_170', 't_171']
# Operações: or
# Saida: k5
#
# Entradas 1: t_170
# Entradas 2: t_171
#
# Partes: ['not', 't_172', 'h3']
# Operações: not
# Saida: t_172
#
# Entrada: h3
#
# Partes: ['not', 't_173', 'e']
# Operações: not
# Saida: t_173
#
# Entrada: e
#
# Partes: ['or', 'l5', 't_172', 't_173']
# Operações: or
# Saida: l5
#
# Entradas 1: t_172
# Entradas 2: t_173
#
# Partes: ['not', 't_174', 'c3']
# Operações: not
# Saida: t_174
#
# Entrada: c3
#
# Partes: ['not', 't_175', 'e']
# Operações: not
# Saida: t_175
#
# Entrada: e
#
# Partes: ['or', 'm5', 't_174', 't_175']
# Operações: or
# Saida: m5
#
# Entradas 1: t_174
# Entradas 2: t_175
#
# Partes: ['not', 't_176', 'd3']
# Operações: not
# Saida: t_176
#
# Entrada: d3
#
# Partes: ['not', 't_177', 'd']
# Operações: not
# Saida: t_177
#
# Entrada: d
#
# Partes: ['or', 'n5', 't_176', 't_177']
# Operações: or
# Saida: n5
#
# Entradas 1: t_176
# Entradas 2: t_177
#
# Partes: ['not', 't_178', 'f3']
# Operações: not
# Saida: t_178
#
# Entrada: f3
#
# Partes: ['not', 't_179', 'd']
# Operações: not
# Saida: t_179
#
# Entrada: d
#
# Partes: ['or', 'o5', 't_178', 't_179']
# Operações: or
# Saida: o5
#
# Entradas 1: t_178
# Entradas 2: t_179
#
# Partes: ['not', 't_180', 'e3']
# Operações: not
# Saida: t_180
#
# Entrada: e3
#
# Partes: ['not', 't_181', 'c']
# Operações: not
# Saida: t_181
#
# Entrada: c
#
# Partes: ['or', 'p5', 't_180', 't_181']
# Operações: or
# Saida: p5
#
# Entradas 1: t_180
# Entradas 2: t_181
#
# Partes: ['not', 't_182', 'f3']
# Operações: not
# Saida: t_182
#
# Entrada: f3
#
# Partes: ['not', 't_183', 'c']
# Operações: not
# Saida: t_183
#
# Entrada: c
#
# Partes: ['or', 'q5', 't_182', 't_183']
# Operações: or
# Saida: q5
#
# Entradas 1: t_182
# Entradas 2: t_183
#
# Partes: ['not', 't_184', 'g3']
# Operações: not
# Saida: t_184
#
# Entrada: g3
#
# Partes: ['not', 't_185', 'b']
# Operações: not
# Saida: t_185
#
# Entrada: b
#
# Partes: ['or', 'r5', 't_184', 't_185']
# Operações: or
# Saida: r5
#
# Entradas 1: t_184
# Entradas 2: t_185
#
# Partes: ['not', 't_186', 'i3']
# Operações: not
# Saida: t_186
#
# Entrada: i3
#
# Partes: ['not', 't_187', 'b']
# Operações: not
# Saida: t_187
#
# Entrada: b
#
# Partes: ['or', 's5', 't_186', 't_187']
# Operações: or
# Saida: s5
#
# Entradas 1: t_186
# Entradas 2: t_187
#
# Partes: ['not', 't_188', 'h3']
# Operações: not
# Saida: t_188
#
# Entrada: h3
#
# Partes: ['not', 't_189', 'a']
# Operações: not
# Saida: t_189
#
# Entrada: a
#
# Partes: ['or', 't5', 't_188', 't_189']
# Operações: or
# Saida: t5
#
# Entradas 1: t_188
# Entradas 2: t_189
#
# Partes: ['not', 't_190', 'i3']
# Operações: not
# Saida: t_190
#
# Entrada: i3
#
# Partes: ['not', 't_191', 'a']
# Operações: not
# Saida: t_191
#
# Entrada: a
#
# Partes: ['or', 'u5', 't_190', 't_191']
# Operações: or
# Saida: u5
#
# Entradas 1: t_190
# Entradas 2: t_191
#
# Partes: ['not', 't_192', 'j3']
# Operações: not
# Saida: t_192
#
# Entrada: j3
#
# Partes: ['not', 't_193', 'r3']
# Operações: not
# Saida: t_193
#
# Entrada: r3
#
# Partes: ['or', 'v5', 't_192', 't_193']
# Operações: or
# Saida: v5
#
# Entradas 1: t_192
# Entradas 2: t_193
#
# Partes: ['not', 't_194', 'k3']
# Operações: not
# Saida: t_194
#
# Entrada: k3
#
# Partes: ['not', 't_195', 'm3']
# Operações: not
# Saida: t_195
#
# Entrada: m3
#
# Partes: ['or', 'w5', 't_194', 't_195']
# Operações: or
# Saida: w5
#
# Entradas 1: t_194
# Entradas 2: t_195
#
# Partes: ['not', 't_196', 'l3']
# Operações: not
# Saida: t_196
#
# Entrada: l3
#
# Partes: ['not', 't_197', 't3']
# Operações: not
# Saida: t_197
#
# Entrada: t3
#
# Partes: ['or', 'x5', 't_196', 't_197']
# Operações: or
# Saida: x5
#
# Entradas 1: t_196
# Entradas 2: t_197
#
# Partes: ['not', 't_198', 'n3']
# Operações: not
# Saida: t_198
#
# Entrada: n3
#
# Partes: ['not', 't_199', 'v3']
# Operações: not
# Saida: t_199
#
# Entrada: v3
#
# Partes: ['or', 'y5', 't_198', 't_199']
# Operações: or
# Saida: y5
#
# Entradas 1: t_198
# Entradas 2: t_199
#
# Partes: ['not', 't_200', 'o3']
# Operações: not
# Saida: t_200
#
# Entrada: o3
#
# Partes: ['not', 't_201', 'q3']
# Operações: not
# Saida: t_201
#
# Entrada: q3
#
# Partes: ['or', 'z5', 't_200', 't_201']
# Operações: or
# Saida: z5
#
# Entradas 1: t_200
# Entradas 2: t_201
#
# Partes: ['not', 't_202', 'p3']
# Operações: not
# Saida: t_202
#
# Entrada: p3
#
# Partes: ['not', 't_203', 'x3']
# Operações: not
# Saida: t_203
#
# Entrada: x3
#
# Partes: ['or', 'a6', 't_202', 't_203']
# Operações: or
# Saida: a6
#
# Entradas 1: t_202
# Entradas 2: t_203
#
# Partes: ['not', 't_204', 's3']
# Operações: not
# Saida: t_204
#
# Entrada: s3
#
# Partes: ['not', 't_205', 'u3']
# Operações: not
# Saida: t_205
#
# Entrada: u3
#
# Partes: ['or', 'b6', 't_204', 't_205']
# Operações: or
# Saida: b6
#
# Entradas 1: t_204
# Entradas 2: t_205
#
# Partes: ['not', 't_206', 'w3']
# Operações: not
# Saida: t_206
#
# Entrada: w3
#
# Partes: ['not', 't_207', 'y3']
# Operações: not
# Saida: t_207
#
# Entrada: y3
#
# Partes: ['or', 'c6', 't_206', 't_207']
# Operações: or
# Saida: c6
#
# Entradas 1: t_206
# Entradas 2: t_207
#
# Partes: ['not', 't_208', 'z3']
# Operações: not
# Saida: t_208
#
# Entrada: z3
#
# Partes: ['not', 't_209', 'h4']
# Operações: not
# Saida: t_209
#
# Entrada: h4
#
# Partes: ['or', 'd6', 't_208', 't_209']
# Operações: or
# Saida: d6
#
# Entradas 1: t_208
# Entradas 2: t_209
#
# Partes: ['not', 't_210', 'a4']
# Operações: not
# Saida: t_210
#
# Entrada: a4
#
# Partes: ['not', 't_211', 'c4']
# Operações: not
# Saida: t_211
#
# Entrada: c4
#
# Partes: ['or', 'e6', 't_210', 't_211']
# Operações: or
# Saida: e6
#
# Entradas 1: t_210
# Entradas 2: t_211
#
# Partes: ['not', 't_212', 'b4']
# Operações: not
# Saida: t_212
#
# Entrada: b4
#
# Partes: ['not', 't_213', 'j4']
# Operações: not
# Saida: t_213
#
# Entrada: j4
#
# Partes: ['or', 'f6', 't_212', 't_213']
# Operações: or
# Saida: f6
#
# Entradas 1: t_212
# Entradas 2: t_213
#
# Partes: ['not', 't_214', 'd4']
# Operações: not
# Saida: t_214
#
# Entrada: d4
#
# Partes: ['not', 't_215', 'l4']
# Operações: not
# Saida: t_215
#
# Entrada: l4
#
# Partes: ['or', 'g6', 't_214', 't_215']
# Operações: or
# Saida: g6
#
# Entradas 1: t_214
# Entradas 2: t_215
#
# Partes: ['not', 't_216', 'e4']
# Operações: not
# Saida: t_216
#
# Entrada: e4
#
# Partes: ['not', 't_217', 'g4']
# Operações: not
# Saida: t_217
#
# Entrada: g4
#
# Partes: ['or', 'h6', 't_216', 't_217']
# Operações: or
# Saida: h6
#
# Entradas 1: t_216
# Entradas 2: t_217
#
# Partes: ['not', 't_218', 'f4']
# Operações: not
# Saida: t_218
#
# Entrada: f4
#
# Partes: ['not', 't_219', 'n4']
# Operações: not
# Saida: t_219
#
# Entrada: n4
#
# Partes: ['or', 'i6', 't_218', 't_219']
# Operações: or
# Saida: i6
#
# Entradas 1: t_218
# Entradas 2: t_219
#
# Partes: ['not', 't_220', 'i4']
# Operações: not
# Saida: t_220
#
# Entrada: i4
#
# Partes: ['not', 't_221', 'k4']
# Operações: not
# Saida: t_221
#
# Entrada: k4
#
# Partes: ['or', 'j6', 't_220', 't_221']
# Operações: or
# Saida: j6
#
# Entradas 1: t_220
# Entradas 2: t_221
#
# Partes: ['not', 't_222', 'm4']
# Operações: not
# Saida: t_222
#
# Entrada: m4
#
# Partes: ['not', 't_223', 'o4']
# Operações: not
# Saida: t_223
#
# Entrada: o4
#
# Partes: ['or', 'k6', 't_222', 't_223']
# Operações: or
# Saida: k6
#
# Entradas 1: t_222
# Entradas 2: t_223
#
# Partes: ['not', 't_224', 'p4']
# Operações: not
# Saida: t_224
#
# Entrada: p4
#
# Partes: ['not', 't_225', 'x4']
# Operações: not
# Saida: t_225
#
# Entrada: x4
#
# Partes: ['or', 'l6', 't_224', 't_225']
# Operações: or
# Saida: l6
#
# Entradas 1: t_224
# Entradas 2: t_225
#
# Partes: ['not', 't_226', 'q4']
# Operações: not
# Saida: t_226
#
# Entrada: q4
#
# Partes: ['not', 't_227', 's4']
# Operações: not
# Saida: t_227
#
# Entrada: s4
#
# Partes: ['or', 'm6', 't_226', 't_227']
# Operações: or
# Saida: m6
#
# Entradas 1: t_226
# Entradas 2: t_227
#
# Partes: ['not', 't_228', 'r4']
# Operações: not
# Saida: t_228
#
# Entrada: r4
#
# Partes: ['not', 't_229', 'z4']
# Operações: not
# Saida: t_229
#
# Entrada: z4
#
# Partes: ['or', 'n6', 't_228', 't_229']
# Operações: or
# Saida: n6
#
# Entradas 1: t_228
# Entradas 2: t_229
#
# Partes: ['not', 't_230', 't4']
# Operações: not
# Saida: t_230
#
# Entrada: t4
#
# Partes: ['not', 't_231', 'b5']
# Operações: not
# Saida: t_231
#
# Entrada: b5
#
# Partes: ['or', 'o6', 't_230', 't_231']
# Operações: or
# Saida: o6
#
# Entradas 1: t_230
# Entradas 2: t_231
#
# Partes: ['not', 't_232', 'u4']
# Operações: not
# Saida: t_232
#
# Entrada: u4
#
# Partes: ['not', 't_233', 'w4']
# Operações: not
# Saida: t_233
#
# Entrada: w4
#
# Partes: ['or', 'p6', 't_232', 't_233']
# Operações: or
# Saida: p6
#
# Entradas 1: t_232
# Entradas 2: t_233
#
# Partes: ['not', 't_234', 'v4']
# Operações: not
# Saida: t_234
#
# Entrada: v4
#
# Partes: ['not', 't_235', 'd5']
# Operações: not
# Saida: t_235
#
# Entrada: d5
#
# Partes: ['or', 'q6', 't_234', 't_235']
# Operações: or
# Saida: q6
#
# Entradas 1: t_234
# Entradas 2: t_235
#
# Partes: ['not', 't_236', 'y4']
# Operações: not
# Saida: t_236
#
# Entrada: y4
#
# Partes: ['not', 't_237', 'a5']
# Operações: not
# Saida: t_237
#
# Entrada: a5
#
# Partes: ['or', 'r6', 't_236', 't_237']
# Operações: or
# Saida: r6
#
# Entradas 1: t_236
# Entradas 2: t_237
#
# Partes: ['not', 't_238', 'c5']
# Operações: not
# Saida: t_238
#
# Entrada: c5
#
# Partes: ['not', 't_239', 'e5']
# Operações: not
# Saida: t_239
#
# Entrada: e5
#
# Partes: ['or', 's6', 't_238', 't_239']
# Operações: or
# Saida: s6
#
# Entradas 1: t_238
# Entradas 2: t_239
#
# Partes: ['not', 't_240', 'f5']
# Operações: not
# Saida: t_240
#
# Entrada: f5
#
# Partes: ['not', 't_241', 'n5']
# Operações: not
# Saida: t_241
#
# Entrada: n5
#
# Partes: ['or', 't6', 't_240', 't_241']
# Operações: or
# Saida: t6
#
# Entradas 1: t_240
# Entradas 2: t_241
#
# Partes: ['not', 't_242', 'g5']
# Operações: not
# Saida: t_242
#
# Entrada: g5
#
# Partes: ['not', 't_243', 'i5']
# Operações: not
# Saida: t_243
#
# Entrada: i5
#
# Partes: ['or', 'u6', 't_242', 't_243']
# Operações: or
# Saida: u6
#
# Entradas 1: t_242
# Entradas 2: t_243
#
# Partes: ['not', 't_244', 'h5']
# Operações: not
# Saida: t_244
#
# Entrada: h5
#
# Partes: ['not', 't_245', 'p5']
# Operações: not
# Saida: t_245
#
# Entrada: p5
#
# Partes: ['or', 'v6', 't_244', 't_245']
# Operações: or
# Saida: v6
#
# Entradas 1: t_244
# Entradas 2: t_245
#
# Partes: ['not', 't_246', 'j5']
# Operações: not
# Saida: t_246
#
# Entrada: j5
#
# Partes: ['not', 't_247', 'r5']
# Operações: not
# Saida: t_247
#
# Entrada: r5
#
# Partes: ['or', 'w6', 't_246', 't_247']
# Operações: or
# Saida: w6
#
# Entradas 1: t_246
# Entradas 2: t_247
#
# Partes: ['not', 't_248', 'k5']
# Operações: not
# Saida: t_248
#
# Entrada: k5
#
# Partes: ['not', 't_249', 'm5']
# Operações: not
# Saida: t_249
#
# Entrada: m5
#
# Partes: ['or', 'x6', 't_248', 't_249']
# Operações: or
# Saida: x6
#
# Entradas 1: t_248
# Entradas 2: t_249
#
# Partes: ['not', 't_250', 'l5']
# Operações: not
# Saida: t_250
#
# Entrada: l5
#
# Partes: ['not', 't_251', 't5']
# Operações: not
# Saida: t_251
#
# Entrada: t5
#
# Partes: ['or', 'y6', 't_250', 't_251']
# Operações: or
# Saida: y6
#
# Entradas 1: t_250
# Entradas 2: t_251
#
# Partes: ['not', 't_252', 'o5']
# Operações: not
# Saida: t_252
#
# Entrada: o5
#
# Partes: ['not', 't_253', 'q5']
# Operações: not
# Saida: t_253
#
# Entrada: q5
#
# Partes: ['or', 'z6', 't_252', 't_253']
# Operações: or
# Saida: z6
#
# Entradas 1: t_252
# Entradas 2: t_253
#
# Partes: ['not', 't_254', 's5']
# Operações: not
# Saida: t_254
#
# Entrada: s5
#
# Partes: ['not', 't_255', 'u5']
# Operações: not
# Saida: t_255
#
# Entrada: u5
#
# Partes: ['or', 'a7', 't_254', 't_255']
# Operações: or
# Saida: a7
#
# Entradas 1: t_254
# Entradas 2: t_255
#
# Partes: ['not', 't_256', 'v5']
# Operações: not
# Saida: t_256
#
# Entrada: v5
#
# Partes: ['not', 't_257', 'd6']
# Operações: not
# Saida: t_257
#
# Entrada: d6
#
# Partes: ['or', 'b7', 't_256', 't_257']
# Operações: or
# Saida: b7
#
# Entradas 1: t_256
# Entradas 2: t_257
#
# Partes: ['not', 't_258', 'w5']
# Operações: not
# Saida: t_258
#
# Entrada: w5
#
# Partes: ['not', 't_259', 'z5']
# Operações: not
# Saida: t_259
#
# Entrada: z5
#
# Partes: ['or', 'c7', 't_258', 't_259']
# Operações: or
# Saida: c7
#
# Entradas 1: t_258
# Entradas 2: t_259
#
# Partes: ['not', 't_260', 'x5']
# Operações: not
# Saida: t_260
#
# Entrada: x5
#
# Partes: ['not', 't_261', 'f6']
# Operações: not
# Saida: t_261
#
# Entrada: f6
#
# Partes: ['or', 'd7', 't_260', 't_261']
# Operações: or
# Saida: d7
#
# Entradas 1: t_260
# Entradas 2: t_261
#
# Partes: ['not', 't_262', 'y5']
# Operações: not
# Saida: t_262
#
# Entrada: y5
#
# Partes: ['not', 't_263', 'g6']
# Operações: not
# Saida: t_263
#
# Entrada: g6
#
# Partes: ['or', 'e7', 't_262', 't_263']
# Operações: or
# Saida: e7
#
# Entradas 1: t_262
# Entradas 2: t_263
#
# Partes: ['not', 't_264', 'a6']
# Operações: not
# Saida: t_264
#
# Entrada: a6
#
# Partes: ['not', 't_265', 'i6']
# Operações: not
# Saida: t_265
#
# Entrada: i6
#
# Partes: ['or', 'f7', 't_264', 't_265']
# Operações: or
# Saida: f7
#
# Entradas 1: t_264
# Entradas 2: t_265
#
# Partes: ['not', 't_266', 'b6']
# Operações: not
# Saida: t_266
#
# Entrada: b6
#
# Partes: ['not', 't_267', 'c6']
# Operações: not
# Saida: t_267
#
# Entrada: c6
#
# Partes: ['or', 'g7', 't_266', 't_267']
# Operações: or
# Saida: g7
#
# Entradas 1: t_266
# Entradas 2: t_267
#
# Partes: ['not', 't_268', 'e6']
# Operações: not
# Saida: t_268
#
# Entrada: e6
#
# Partes: ['not', 't_269', 'h6']
# Operações: not
# Saida: t_269
#
# Entrada: h6
#
# Partes: ['or', 'h7', 't_268', 't_269']
# Operações: or
# Saida: h7
#
# Entradas 1: t_268
# Entradas 2: t_269
#
# Partes: ['not', 't_270', 'j6']
# Operações: not
# Saida: t_270
#
# Entrada: j6
#
# Partes: ['not', 't_271', 'k6']
# Operações: not
# Saida: t_271
#
# Entrada: k6
#
# Partes: ['or', 'i7', 't_270', 't_271']
# Operações: or
# Saida: i7
#
# Entradas 1: t_270
# Entradas 2: t_271
#
# Partes: ['not', 't_272', 'l6']
# Operações: not
# Saida: t_272
#
# Entrada: l6
#
# Partes: ['not', 't_273', 't6']
# Operações: not
# Saida: t_273
#
# Entrada: t6
#
# Partes: ['or', 'j7', 't_272', 't_273']
# Operações: or
# Saida: j7
#
# Entradas 1: t_272
# Entradas 2: t_273
#
# Partes: ['not', 't_274', 'm6']
# Operações: not
# Saida: t_274
#
# Entrada: m6
#
# Partes: ['not', 't_275', 'p6']
# Operações: not
# Saida: t_275
#
# Entrada: p6
#
# Partes: ['or', 'k7', 't_274', 't_275']
# Operações: or
# Saida: k7
#
# Entradas 1: t_274
# Entradas 2: t_275
#
# Partes: ['not', 't_276', 'n6']
# Operações: not
# Saida: t_276
#
# Entrada: n6
#
# Partes: ['not', 't_277', 'v6']
# Operações: not
# Saida: t_277
#
# Entrada: v6
#
# Partes: ['or', 'l7', 't_276', 't_277']
# Operações: or
# Saida: l7
#
# Entradas 1: t_276
# Entradas 2: t_277
#
# Partes: ['not', 't_278', 'o6']
# Operações: not
# Saida: t_278
#
# Entrada: o6
#
# Partes: ['not', 't_279', 'w6']
# Operações: not
# Saida: t_279
#
# Entrada: w6
#
# Partes: ['or', 'm7', 't_278', 't_279']
# Operações: or
# Saida: m7
#
# Entradas 1: t_278
# Entradas 2: t_279
#
# Partes: ['not', 't_280', 'q6']
# Operações: not
# Saida: t_280
#
# Entrada: q6
#
# Partes: ['not', 't_281', 'y6']
# Operações: not
# Saida: t_281
#
# Entrada: y6
#
# Partes: ['or', 'n7', 't_280', 't_281']
# Operações: or
# Saida: n7
#
# Entradas 1: t_280
# Entradas 2: t_281
#
# Partes: ['not', 't_282', 'r6']
# Operações: not
# Saida: t_282
#
# Entrada: r6
#
# Partes: ['not', 't_283', 's6']
# Operações: not
# Saida: t_283
#
# Entrada: s6
#
# Partes: ['or', 'o7', 't_282', 't_283']
# Operações: or
# Saida: o7
#
# Entradas 1: t_282
# Entradas 2: t_283
#
# Partes: ['not', 't_284', 'u6']
# Operações: not
# Saida: t_284
#
# Entrada: u6
#
# Partes: ['not', 't_285', 'x6']
# Operações: not
# Saida: t_285
#
# Entrada: x6
#
# Partes: ['or', 'p7', 't_284', 't_285']
# Operações: or
# Saida: p7
#
# Entradas 1: t_284
# Entradas 2: t_285
#
# Partes: ['not', 't_286', 'z6']
# Operações: not
# Saida: t_286
#
# Entrada: z6
#
# Partes: ['not', 't_287', 'a7']
# Operações: not
# Saida: t_287
#
# Entrada: a7
#
# Partes: ['or', 'q7', 't_286', 't_287']
# Operações: or
# Saida: q7
#
# Entradas 1: t_286
# Entradas 2: t_287
#
# Partes: ['not', 't_288', 'b7']
# Operações: not
# Saida: t_288
#
# Entrada: b7
#
# Partes: ['not', 't_289', 'v5']
# Operações: not
# Saida: t_289
#
# Entrada: v5
#
# Partes: ['or', 'r7', 't_288', 't_289']
# Operações: or
# Saida: r7
#
# Entradas 1: t_288
# Entradas 2: t_289
#
# Partes: ['not', 't_290', 'c7']
# Operações: not
# Saida: t_290
#
# Entrada: c7
#
# Partes: ['not', 't_291', 'w5']
# Operações: not
# Saida: t_291
#
# Entrada: w5
#
# Partes: ['or', 's7', 't_290', 't_291']
# Operações: or
# Saida: s7
#
# Entradas 1: t_290
# Entradas 2: t_291
#
# Partes: ['not', 't_292', 'd7']
# Operações: not
# Saida: t_292
#
# Entrada: d7
#
# Partes: ['not', 't_293', 'x5']
# Operações: not
# Saida: t_293
#
# Entrada: x5
#
# Partes: ['or', 't7', 't_292', 't_293']
# Operações: or
# Saida: t7
#
# Entradas 1: t_292
# Entradas 2: t_293
#
# Partes: ['not', 't_294', 'e7']
# Operações: not
# Saida: t_294
#
# Entrada: e7
#
# Partes: ['not', 't_295', 'y5']
# Operações: not
# Saida: t_295
#
# Entrada: y5
#
# Partes: ['or', 'u7', 't_294', 't_295']
# Operações: or
# Saida: u7
#
# Entradas 1: t_294
# Entradas 2: t_295
#
# Partes: ['not', 't_296', 'c7']
# Operações: not
# Saida: t_296
#
# Entrada: c7
#
# Partes: ['not', 't_297', 'z5']
# Operações: not
# Saida: t_297
#
# Entrada: z5
#
# Partes: ['or', 'v7', 't_296', 't_297']
# Operações: or
# Saida: v7
#
# Entradas 1: t_296
# Entradas 2: t_297
#
# Partes: ['not', 't_298', 'f7']
# Operações: not
# Saida: t_298
#
# Entrada: f7
#
# Partes: ['not', 't_299', 'a6']
# Operações: not
# Saida: t_299
#
# Entrada: a6
#
# Partes: ['or', 'w7', 't_298', 't_299']
# Operações: or
# Saida: w7
#
# Entradas 1: t_298
# Entradas 2: t_299
#
# Partes: ['not', 't_300', 'g7']
# Operações: not
# Saida: t_300
#
# Entrada: g7
#
# Partes: ['not', 't_301', 'b6']
# Operações: not
# Saida: t_301
#
# Entrada: b6
#
# Partes: ['or', 'x7', 't_300', 't_301']
# Operações: or
# Saida: x7
#
# Entradas 1: t_300
# Entradas 2: t_301
#
# Partes: ['not', 't_302', 'g7']
# Operações: not
# Saida: t_302
#
# Entrada: g7
#
# Partes: ['not', 't_303', 'c6']
# Operações: not
# Saida: t_303
#
# Entrada: c6
#
# Partes: ['or', 'y7', 't_302', 't_303']
# Operações: or
# Saida: y7
#
# Entradas 1: t_302
# Entradas 2: t_303
#
# Partes: ['not', 't_304', 'b7']
# Operações: not
# Saida: t_304
#
# Entrada: b7
#
# Partes: ['not', 't_305', 'd6']
# Operações: not
# Saida: t_305
#
# Entrada: d6
#
# Partes: ['or', 'z7', 't_304', 't_305']
# Operações: or
# Saida: z7
#
# Entradas 1: t_304
# Entradas 2: t_305
#
# Partes: ['not', 't_306', 'h7']
# Operações: not
# Saida: t_306
#
# Entrada: h7
#
# Partes: ['not', 't_307', 'e6']
# Operações: not
# Saida: t_307
#
# Entrada: e6
#
# Partes: ['or', 'a8', 't_306', 't_307']
# Operações: or
# Saida: a8
#
# Entradas 1: t_306
# Entradas 2: t_307
#
# Partes: ['not', 't_308', 'd7']
# Operações: not
# Saida: t_308
#
# Entrada: d7
#
# Partes: ['not', 't_309', 'f6']
# Operações: not
# Saida: t_309
#
# Entrada: f6
#
# Partes: ['or', 'b8', 't_308', 't_309']
# Operações: or
# Saida: b8
#
# Entradas 1: t_308
# Entradas 2: t_309
#
# Partes: ['not', 't_310', 'e7']
# Operações: not
# Saida: t_310
#
# Entrada: e7
#
# Partes: ['not', 't_311', 'g6']
# Operações: not
# Saida: t_311
#
# Entrada: g6
#
# Partes: ['or', 'c8', 't_310', 't_311']
# Operações: or
# Saida: c8
#
# Entradas 1: t_310
# Entradas 2: t_311
#
# Partes: ['not', 't_312', 'h7']
# Operações: not
# Saida: t_312
#
# Entrada: h7
#
# Partes: ['not', 't_313', 'h6']
# Operações: not
# Saida: t_313
#
# Entrada: h6
#
# Partes: ['or', 'd8', 't_312', 't_313']
# Operações: or
# Saida: d8
#
# Entradas 1: t_312
# Entradas 2: t_313
#
# Partes: ['not', 't_314', 'f7']
# Operações: not
# Saida: t_314
#
# Entrada: f7
#
# Partes: ['not', 't_315', 'i6']
# Operações: not
# Saida: t_315
#
# Entrada: i6
#
# Partes: ['or', 'e8', 't_314', 't_315']
# Operações: or
# Saida: e8
#
# Entradas 1: t_314
# Entradas 2: t_315
#
# Partes: ['not', 't_316', 'i7']
# Operações: not
# Saida: t_316
#
# Entrada: i7
#
# Partes: ['not', 't_317', 'j6']
# Operações: not
# Saida: t_317
#
# Entrada: j6
#
# Partes: ['or', 'f8', 't_316', 't_317']
# Operações: or
# Saida: f8
#
# Entradas 1: t_316
# Entradas 2: t_317
#
# Partes: ['not', 't_318', 'i7']
# Operações: not
# Saida: t_318
#
# Entrada: i7
#
# Partes: ['not', 't_319', 'k6']
# Operações: not
# Saida: t_319
#
# Entrada: k6
#
# Partes: ['or', 'g8', 't_318', 't_319']
# Operações: or
# Saida: g8
#
# Entradas 1: t_318
# Entradas 2: t_319
#
# Partes: ['not', 't_320', 'j7']
# Operações: not
# Saida: t_320
#
# Entrada: j7
#
# Partes: ['not', 't_321', 'l6']
# Operações: not
# Saida: t_321
#
# Entrada: l6
#
# Partes: ['or', 'h8', 't_320', 't_321']
# Operações: or
# Saida: h8
#
# Entradas 1: t_320
# Entradas 2: t_321
#
# Partes: ['not', 't_322', 'k7']
# Operações: not
# Saida: t_322
#
# Entrada: k7
#
# Partes: ['not', 't_323', 'm6']
# Operações: not
# Saida: t_323
#
# Entrada: m6
#
# Partes: ['or', 'i8', 't_322', 't_323']
# Operações: or
# Saida: i8
#
# Entradas 1: t_322
# Entradas 2: t_323
#
# Partes: ['not', 't_324', 'l7']
# Operações: not
# Saida: t_324
#
# Entrada: l7
#
# Partes: ['not', 't_325', 'n6']
# Operações: not
# Saida: t_325
#
# Entrada: n6
#
# Partes: ['or', 'j8', 't_324', 't_325']
# Operações: or
# Saida: j8
#
# Entradas 1: t_324
# Entradas 2: t_325
#
# Partes: ['not', 't_326', 'm7']
# Operações: not
# Saida: t_326
#
# Entrada: m7
#
# Partes: ['not', 't_327', 'o6']
# Operações: not
# Saida: t_327
#
# Entrada: o6
#
# Partes: ['or', 'k8', 't_326', 't_327']
# Operações: or
# Saida: k8
#
# Entradas 1: t_326
# Entradas 2: t_327
#
# Partes: ['not', 't_328', 'k7']
# Operações: not
# Saida: t_328
#
# Entrada: k7
#
# Partes: ['not', 't_329', 'p6']
# Operações: not
# Saida: t_329
#
# Entrada: p6
#
# Partes: ['or', 'l8', 't_328', 't_329']
# Operações: or
# Saida: l8
#
# Entradas 1: t_328
# Entradas 2: t_329
#
# Partes: ['not', 't_330', 'n7']
# Operações: not
# Saida: t_330
#
# Entrada: n7
#
# Partes: ['not', 't_331', 'q6']
# Operações: not
# Saida: t_331
#
# Entrada: q6
#
# Partes: ['or', 'm8', 't_330', 't_331']
# Operações: or
# Saida: m8
#
# Entradas 1: t_330
# Entradas 2: t_331
#
# Partes: ['not', 't_332', 'o7']
# Operações: not
# Saida: t_332
#
# Entrada: o7
#
# Partes: ['not', 't_333', 'r6']
# Operações: not
# Saida: t_333
#
# Entrada: r6
#
# Partes: ['or', 'n8', 't_332', 't_333']
# Operações: or
# Saida: n8
#
# Entradas 1: t_332
# Entradas 2: t_333
#
# Partes: ['not', 't_334', 'o7']
# Operações: not
# Saida: t_334
#
# Entrada: o7
#
# Partes: ['not', 't_335', 's6']
# Operações: not
# Saida: t_335
#
# Entrada: s6
#
# Partes: ['or', 'o8', 't_334', 't_335']
# Operações: or
# Saida: o8
#
# Entradas 1: t_334
# Entradas 2: t_335
#
# Partes: ['not', 't_336', 'j7']
# Operações: not
# Saida: t_336
#
# Entrada: j7
#
# Partes: ['not', 't_337', 't6']
# Operações: not
# Saida: t_337
#
# Entrada: t6
#
# Partes: ['or', 'p8', 't_336', 't_337']
# Operações: or
# Saida: p8
#
# Entradas 1: t_336
# Entradas 2: t_337
#
# Partes: ['not', 't_338', 'p7']
# Operações: not
# Saida: t_338
#
# Entrada: p7
#
# Partes: ['not', 't_339', 'u6']
# Operações: not
# Saida: t_339
#
# Entrada: u6
#
# Partes: ['or', 'q8', 't_338', 't_339']
# Operações: or
# Saida: q8
#
# Entradas 1: t_338
# Entradas 2: t_339
#
# Partes: ['not', 't_340', 'l7']
# Operações: not
# Saida: t_340
#
# Entrada: l7
#
# Partes: ['not', 't_341', 'v6']
# Operações: not
# Saida: t_341
#
# Entrada: v6
#
# Partes: ['or', 'r8', 't_340', 't_341']
# Operações: or
# Saida: r8
#
# Entradas 1: t_340
# Entradas 2: t_341
#
# Partes: ['not', 't_342', 'm7']
# Operações: not
# Saida: t_342
#
# Entrada: m7
#
# Partes: ['not', 't_343', 'w6']
# Operações: not
# Saida: t_343
#
# Entrada: w6
#
# Partes: ['or', 's8', 't_342', 't_343']
# Operações: or
# Saida: s8
#
# Entradas 1: t_342
# Entradas 2: t_343
#
# Partes: ['not', 't_344', 'p7']
# Operações: not
# Saida: t_344
#
# Entrada: p7
#
# Partes: ['not', 't_345', 'x6']
# Operações: not
# Saida: t_345
#
# Entrada: x6
#
# Partes: ['or', 't8', 't_344', 't_345']
# Operações: or
# Saida: t8
#
# Entradas 1: t_344
# Entradas 2: t_345
#
# Partes: ['not', 't_346', 'n7']
# Operações: not
# Saida: t_346
#
# Entrada: n7
#
# Partes: ['not', 't_347', 'y6']
# Operações: not
# Saida: t_347
#
# Entrada: y6
#
# Partes: ['or', 'u8', 't_346', 't_347']
# Operações: or
# Saida: u8
#
# Entradas 1: t_346
# Entradas 2: t_347
#
# Partes: ['not', 't_348', 'q7']
# Operações: not
# Saida: t_348
#
# Entrada: q7
#
# Partes: ['not', 't_349', 'z6']
# Operações: not
# Saida: t_349
#
# Entrada: z6
#
# Partes: ['or', 'v8', 't_348', 't_349']
# Operações: or
# Saida: v8
#
# Entradas 1: t_348
# Entradas 2: t_349
#
# Partes: ['not', 't_350', 'q7']
# Operações: not
# Saida: t_350
#
# Entrada: q7
#
# Partes: ['not', 't_351', 'a7']
# Operações: not
# Saida: t_351
#
# Entrada: a7
#
# Partes: ['or', 'w8', 't_350', 't_351']
# Operações: or
# Saida: w8
#
# Entradas 1: t_350
# Entradas 2: t_351
#
# Partes: ['not', 't_352', 'r7']
# Operações: not
# Saida: t_352
#
# Entrada: r7
#
# Partes: ['not', 't_353', 'z7']
# Operações: not
# Saida: t_353
#
# Entrada: z7
#
# Partes: ['or', 'x8', 't_352', 't_353']
# Operações: or
# Saida: x8
#
# Entradas 1: t_352
# Entradas 2: t_353
#
# Partes: ['not', 't_354', 's7']
# Operações: not
# Saida: t_354
#
# Entrada: s7
#
# Partes: ['not', 't_355', 'v7']
# Operações: not
# Saida: t_355
#
# Entrada: v7
#
# Partes: ['or', 'y8', 't_354', 't_355']
# Operações: or
# Saida: y8
#
# Entradas 1: t_354
# Entradas 2: t_355
#
# Partes: ['not', 't_356', 't7']
# Operações: not
# Saida: t_356
#
# Entrada: t7
#
# Partes: ['not', 't_357', 'b8']
# Operações: not
# Saida: t_357
#
# Entrada: b8
#
# Partes: ['or', 'z8', 't_356', 't_357']
# Operações: or
# Saida: z8
#
# Entradas 1: t_356
# Entradas 2: t_357
#
# Partes: ['not', 't_358', 'u7']
# Operações: not
# Saida: t_358
#
# Entrada: u7
#
# Partes: ['not', 't_359', 'c8']
# Operações: not
# Saida: t_359
#
# Entrada: c8
#
# Partes: ['or', 'a9', 't_358', 't_359']
# Operações: or
# Saida: a9
#
# Entradas 1: t_358
# Entradas 2: t_359
#
# Partes: ['not', 't_360', 'w7']
# Operações: not
# Saida: t_360
#
# Entrada: w7
#
# Partes: ['not', 't_361', 'e8']
# Operações: not
# Saida: t_361
#
# Entrada: e8
#
# Partes: ['or', 'b9', 't_360', 't_361']
# Operações: or
# Saida: b9
#
# Entradas 1: t_360
# Entradas 2: t_361
#
# Partes: ['not', 't_362', 'x7']
# Operações: not
# Saida: t_362
#
# Entrada: x7
#
# Partes: ['not', 't_363', 'y7']
# Operações: not
# Saida: t_363
#
# Entrada: y7
#
# Partes: ['or', 'c9', 't_362', 't_363']
# Operações: or
# Saida: c9
#
# Entradas 1: t_362
# Entradas 2: t_363
#
# Partes: ['not', 't_364', 'a8']
# Operações: not
# Saida: t_364
#
# Entrada: a8
#
# Partes: ['not', 't_365', 'd8']
# Operações: not
# Saida: t_365
#
# Entrada: d8
#
# Partes: ['or', 'd9', 't_364', 't_365']
# Operações: or
# Saida: d9
#
# Entradas 1: t_364
# Entradas 2: t_365
#
# Partes: ['not', 't_366', 'f8']
# Operações: not
# Saida: t_366
#
# Entrada: f8
#
# Partes: ['not', 't_367', 'g8']
# Operações: not
# Saida: t_367
#
# Entrada: g8
#
# Partes: ['or', 'e9', 't_366', 't_367']
# Operações: or
# Saida: e9
#
# Entradas 1: t_366
# Entradas 2: t_367
#
# Partes: ['not', 't_368', 'h8']
# Operações: not
# Saida: t_368
#
# Entrada: h8
#
# Partes: ['not', 't_369', 'p8']
# Operações: not
# Saida: t_369
#
# Entrada: p8
#
# Partes: ['or', 'f9', 't_368', 't_369']
# Operações: or
# Saida: f9
#
# Entradas 1: t_368
# Entradas 2: t_369
#
# Partes: ['not', 't_370', 'i8']
# Operações: not
# Saida: t_370
#
# Entrada: i8
#
# Partes: ['not', 't_371', 'l8']
# Operações: not
# Saida: t_371
#
# Entrada: l8
#
# Partes: ['or', 'g9', 't_370', 't_371']
# Operações: or
# Saida: g9
#
# Entradas 1: t_370
# Entradas 2: t_371
#
# Partes: ['not', 't_372', 'j8']
# Operações: not
# Saida: t_372
#
# Entrada: j8
#
# Partes: ['not', 't_373', 'r8']
# Operações: not
# Saida: t_373
#
# Entrada: r8
#
# Partes: ['or', 'h9', 't_372', 't_373']
# Operações: or
# Saida: h9
#
# Entradas 1: t_372
# Entradas 2: t_373
#
# Partes: ['not', 't_374', 'k8']
# Operações: not
# Saida: t_374
#
# Entrada: k8
#
# Partes: ['not', 't_375', 's8']
# Operações: not
# Saida: t_375
#
# Entrada: s8
#
# Partes: ['or', 'i9', 't_374', 't_375']
# Operações: or
# Saida: i9
#
# Entradas 1: t_374
# Entradas 2: t_375
#
# Partes: ['not', 't_376', 'm8']
# Operações: not
# Saida: t_376
#
# Entrada: m8
#
# Partes: ['not', 't_377', 'u8']
# Operações: not
# Saida: t_377
#
# Entrada: u8
#
# Partes: ['or', 'j9', 't_376', 't_377']
# Operações: or
# Saida: j9
#
# Entradas 1: t_376
# Entradas 2: t_377
#
# Partes: ['not', 't_378', 'n8']
# Operações: not
# Saida: t_378
#
# Entrada: n8
#
# Partes: ['not', 't_379', 'o8']
# Operações: not
# Saida: t_379
#
# Entrada: o8
#
# Partes: ['or', 'k9', 't_378', 't_379']
# Operações: or
# Saida: k9
#
# Entradas 1: t_378
# Entradas 2: t_379
#
# Partes: ['not', 't_380', 'q8']
# Operações: not
# Saida: t_380
#
# Entrada: q8
#
# Partes: ['not', 't_381', 't8']
# Operações: not
# Saida: t_381
#
# Entrada: t8
#
# Partes: ['or', 'l9', 't_380', 't_381']
# Operações: or
# Saida: l9
#
# Entradas 1: t_380
# Entradas 2: t_381
#
# Partes: ['not', 't_382', 'v8']
# Operações: not
# Saida: t_382
#
# Entrada: v8
#
# Partes: ['not', 't_383', 'w8']
# Operações: not
# Saida: t_383
#
# Entrada: w8
#
# Partes: ['or', 'm9', 't_382', 't_383']
# Operações: or
# Saida: m9
#
# Entradas 1: t_382
# Entradas 2: t_383
#
# Partes: ['not', 't_384', 'y8']
# Operações: not
# Saida: t_384
#
# Entrada: y8
#
# Partes: ['not', 't_385', 'c9']
# Operações: not
# Saida: t_385
#
# Entrada: c9
#
# Partes: ['or', 'n9', 't_384', 't_385']
# Operações: or
# Saida: n9
#
# Entradas 1: t_384
# Entradas 2: t_385
#
# Partes: ['not', 't_386', 'y8']
# Operações: not
# Saida: t_386
#
# Entrada: y8
#
# Partes: ['not', 't_387', 'd9']
# Operações: not
# Saida: t_387
#
# Entrada: d9
#
# Partes: ['or', 'o9', 't_386', 't_387']
# Operações: or
# Saida: o9
#
# Entradas 1: t_386
# Entradas 2: t_387
#
# ...
# Operações: not
# Saida: t_704
#
# Entrada: r16
#
# Partes: ['not', 't_705', 'f0']
# Operações: not
# Saida: t_705
#
# Entrada: f0
#
# Partes: ['or', 'd19', 't_704', 't_705']
# Operações: or
# Saida: d19
#
# Entradas 1: t_704
# Entradas 2: t_705
#
# Partes: ['not', 't_706', 's16']
# Operações: not
# Saida: t_706
#
# Entrada: s16
#
# Partes: ['not', 't_707', 'e0']
# Operações: not
# Saida: t_707
#
# Entrada: e0
#
# Partes: ['or', 'e19', 't_706', 't_707']
# Operações: or
# Saida: e19
#
# Entradas 1: t_706
# Entradas 2: t_707
#
# Partes: ['not', 't_708', 't16']
# Operações: not
# Saida: t_708
#
# Entrada: t16
#
# Partes: ['not', 't_709', 'd0']
# Operações: not
# Saida: t_709
#
# Entrada: d0
#
# Partes: ['or', 'f19', 't_708', 't_709']
# Operações: or
# Saida: f19
#
# Entradas 1: t_708
# Entradas 2: t_709
#
# Partes: ['not', 't_710', 'u16']
# Operações: not
# Saida: t_710
#
# Entrada: u16
#
# Partes: ['not', 't_711', 'c0']
# Operações: not
# Saida: t_711
#
# Entrada: c0
#
# Partes: ['or', 'g19', 't_710', 't_711']
# Operações: or
# Saida: g19
#
# Entradas 1: t_710
# Entradas 2: t_711
#
# Partes: ['not', 't_712', 'v16']
# Operações: not
# Saida: t_712
#
# Entrada: v16
#
# Partes: ['not', 't_713', 'b0']
# Operações: not
# Saida: t_713
#
# Entrada: b0
#
# Partes: ['or', 'h19', 't_712', 't_713']
# Operações: or
# Saida: h19
#
# Entradas 1: t_712
# Entradas 2: t_713
#
# Partes: ['not', 't_714', 'w16']
# Operações: not
# Saida: t_714
#
# Entrada: w16
#
# Partes: ['not', 't_715', 'a0']
# Operações: not
# Saida: t_715
#
# Entrada: a0
#
# Partes: ['or', 'i19', 't_714', 't_715']
# Operações: or
# Saida: i19
#
# Entradas 1: t_714
# Entradas 2: t_715
#
# Partes: ['not', 't_716', 'x16']
# Operações: not
# Saida: t_716
#
# Entrada: x16
#
# Partes: ['not', 't_717', 'z']
# Operações: not
# Saida: t_717
#
# Entrada: z
#
# Partes: ['or', 'j19', 't_716', 't_717']
# Operações: or
# Saida: j19
#
# Entradas 1: t_716
# Entradas 2: t_717
#
# Partes: ['not', 't_718', 'y16']
# Operações: not
# Saida: t_718
#
# Entrada: y16
#
# Partes: ['not', 't_719', 'y']
# Operações: not
# Saida: t_719
#
# Entrada: y
#
# Partes: ['or', 'k19', 't_718', 't_719']
# Operações: or
# Saida: k19
#
# Entradas 1: t_718
# Entradas 2: t_719
#
# Partes: ['not', 't_720', 'z16']
# Operações: not
# Saida: t_720
#
# Entrada: z16
#
# Partes: ['not', 't_721', 'x']
# Operações: not
# Saida: t_721
#
# Entrada: x
#
# Partes: ['or', 'l19', 't_720', 't_721']
# Operações: or
# Saida: l19
#
# Entradas 1: t_720
# Entradas 2: t_721
#
# Partes: ['not', 't_722', 'a17']
# Operações: not
# Saida: t_722
#
# Entrada: a17
#
# Partes: ['not', 't_723', 'w']
# Operações: not
# Saida: t_723
#
# Entrada: w
#
# Partes: ['or', 'm19', 't_722', 't_723']
# Operações: or
# Saida: m19
#
# Entradas 1: t_722
# Entradas 2: t_723
#
# Partes: ['not', 't_724', 'b17']
# Operações: not
# Saida: t_724
#
# Entrada: b17
#
# Partes: ['not', 't_725', 'v']
# Operações: not
# Saida: t_725
#
# Entrada: v
#
# Partes: ['or', 'n19', 't_724', 't_725']
# Operações: or
# Saida: n19
#
# Entradas 1: t_724
# Entradas 2: t_725
#
# Partes: ['not', 't_726', 'c17']
# Operações: not
# Saida: t_726
#
# Entrada: c17
#
# Partes: ['not', 't_727', 'u']
# Operações: not
# Saida: t_727
#
# Entrada: u
#
# Partes: ['or', 'o19', 't_726', 't_727']
# Operações: or
# Saida: o19
#
# Entradas 1: t_726
# Entradas 2: t_727
#
# Partes: ['not', 't_728', 'd17']
# Operações: not
# Saida: t_728
#
# Entrada: d17
#
# Partes: ['not', 't_729', 't']
# Operações: not
# Saida: t_729
#
# Entrada: t
#
# Partes: ['or', 'p19', 't_728', 't_729']
# Operações: or
# Saida: p19
#
# Entradas 1: t_728
# Entradas 2: t_729
#
# Partes: ['not', 't_730', 'e17']
# Operações: not
# Saida: t_730
#
# Entrada: e17
#
# Partes: ['not', 't_731', 's']
# Operações: not
# Saida: t_731
#
# Entrada: s
#
# Partes: ['or', 'q19', 't_730', 't_731']
# Operações: or
# Saida: q19
#
# Entradas 1: t_730
# Entradas 2: t_731
#
# Partes: ['not', 't_732', 'f17']
# Operações: not
# Saida: t_732
#
# Entrada: f17
#
# Partes: ['not', 't_733', 'r']
# Operações: not
# Saida: t_733
#
# Entrada: r
#
# Partes: ['or', 'r19', 't_732', 't_733']
# Operações: or
# Saida: r19
#
# Entradas 1: t_732
# Entradas 2: t_733
#
# Partes: ['not', 't_734', 'g17']
# Operações: not
# Saida: t_734
#
# Entrada: g17
#
# Partes: ['not', 't_735', 'q']
# Operações: not
# Saida: t_735
#
# Entrada: q
#
# Partes: ['or', 's19', 't_734', 't_735']
# Operações: or
# Saida: s19
#
# Entradas 1: t_734
# Entradas 2: t_735
#
# Partes: ['not', 't_736', 'h17']
# Operações: not
# Saida: t_736
#
# Entrada: h17
#
# Partes: ['not', 't_737', 'p']
# Operações: not
# Saida: t_737
#
# Entrada: p
#
# Partes: ['or', 't19', 't_736', 't_737']
# Operações: or
# Saida: t19
#
# Entradas 1: t_736
# Entradas 2: t_737
#
# Partes: ['not', 't_738', 'i17']
# Operações: not
# Saida: t_738
#
# Entrada: i17
#
# Partes: ['not', 't_739', 'o']
# Operações: not
# Saida: t_739
#
# Entrada: o
#
# Partes: ['or', 'u19', 't_738', 't_739']
# Operações: or
# Saida: u19
#
# Entradas 1: t_738
# Entradas 2: t_739
#
# Partes: ['not', 't_740', 'j17']
# Operações: not
# Saida: t_740
#
# Entrada: j17
#
# Partes: ['not', 't_741', 'n']
# Operações: not
# Saida: t_741
#
# Entrada: n
#
# Partes: ['or', 'v19', 't_740', 't_741']
# Operações: or
# Saida: v19
#
# Entradas 1: t_740
# Entradas 2: t_741
#
# Partes: ['not', 't_742', 'k17']
# Operações: not
# Saida: t_742
#
# Entrada: k17
#
# Partes: ['not', 't_743', 'm']
# Operações: not
# Saida: t_743
#
# Entrada: m
#
# Partes: ['or', 'w19', 't_742', 't_743']
# Operações: or
# Saida: w19
#
# Entradas 1: t_742
# Entradas 2: t_743
#
# Partes: ['not', 't_744', 'l17']
# Operações: not
# Saida: t_744
#
# Entrada: l17
#
# Partes: ['not', 't_745', 'l']
# Operações: not
# Saida: t_745
#
# Entrada: l
#
# Partes: ['or', 'x19', 't_744', 't_745']
# Operações: or
# Saida: x19
#
# Entradas 1: t_744
# Entradas 2: t_745
#
# Partes: ['not', 't_746', 'm17']
# Operações: not
# Saida: t_746
#
# Entrada: m17
#
# Partes: ['not', 't_747', 'k']
# Operações: not
# Saida: t_747
#
# Entrada: k
#
# Partes: ['or', 'y19', 't_746', 't_747']
# Operações: or
# Saida: y19
#
# Entradas 1: t_746
# Entradas 2: t_747
#
# Partes: ['not', 't_748', 'n17']
# Operações: not
# Saida: t_748
#
# Entrada: n17
#
# Partes: ['not', 't_749', 'j']
# Operações: not
# Saida: t_749
#
# Entrada: j
#
# Partes: ['or', 'z19', 't_748', 't_749']
# Operações: or
# Saida: z19
#
# Entradas 1: t_748
# Entradas 2: t_749
#
# Partes: ['not', 't_750', 'o17']
# Operações: not
# Saida: t_750
#
# Entrada: o17
#
# Partes: ['not', 't_751', 'i']
# Operações: not
# Saida: t_751
#
# Entrada: i
#
# Partes: ['or', 'a20', 't_750', 't_751']
# Operações: or
# Saida: a20
#
# Entradas 1: t_750
# Entradas 2: t_751
#
# Partes: ['not', 't_752', 'p17']
# Operações: not
# Saida: t_752
#
# Entrada: p17
#
# Partes: ['not', 't_753', 'h']
# Operações: not
# Saida: t_753
#
# Entrada: h
#
# Partes: ['or', 'b20', 't_752', 't_753']
# Operações: or
# Saida: b20
#
# Entradas 1: t_752
# Entradas 2: t_753
#
# Partes: ['not', 't_754', 'q17']
# Operações: not
# Saida: t_754
#
# Entrada: q17
#
# Partes: ['not', 't_755', 'g']
# Operações: not
# Saida: t_755
#
# Entrada: g
#
# Partes: ['or', 'c20', 't_754', 't_755']
# Operações: or
# Saida: c20
#
# Entradas 1: t_754
# Entradas 2: t_755
#
# Partes: ['not', 't_756', 'r17']
# Operações: not
# Saida: t_756
#
# Entrada: r17
#
# Partes: ['not', 't_757', 'f']
# Operações: not
# Saida: t_757
#
# Entrada: f
#
# Partes: ['or', 'd20', 't_756', 't_757']
# Operações: or
# Saida: d20
#
# Entradas 1: t_756
# Entradas 2: t_757
#
# Partes: ['not', 't_758', 's17']
# Operações: not
# Saida: t_758
#
# Entrada: s17
#
# Partes: ['not', 't_759', 'e']
# Operações: not
# Saida: t_759
#
# Entrada: e
#
# Partes: ['or', 'e20', 't_758', 't_759']
# Operações: or
# Saida: e20
#
# Entradas 1: t_758
# Entradas 2: t_759
#
# Partes: ['not', 't_760', 't17']
# Operações: not
# Saida: t_760
#
# Entrada: t17
#
# Partes: ['not', 't_761', 'd']
# Operações: not
# Saida: t_761
#
# Entrada: d
#
# Partes: ['or', 'f20', 't_760', 't_761']
# Operações: or
# Saida: f20
#
# Entradas 1: t_760
# Entradas 2: t_761
#
# Partes: ['not', 't_762', 'u17']
# Operações: not
# Saida: t_762
#
# Entrada: u17
#
# Partes: ['not', 't_763', 'c']
# Operações: not
# Saida: t_763
#
# Entrada: c
#
# Partes: ['or', 'g20', 't_762', 't_763']
# Operações: or
# Saida: g20
#
# Entradas 1: t_762
# Entradas 2: t_763
#
# Partes: ['not', 't_764', 'v17']
# Operações: not
# Saida: t_764
#
# Entrada: v17
#
# Partes: ['not', 't_765', 'b']
# Operações: not
# Saida: t_765
#
# Entrada: b
#
# Partes: ['or', 'h20', 't_764', 't_765']
# Operações: or
# Saida: h20
#
# Entradas 1: t_764
# Entradas 2: t_765
#
# Partes: ['not', 't_766', 'w17']
# Operações: not
# Saida: t_766
#
# Entrada: w17
#
# Partes: ['not', 't_767', 'a']
# Operações: not
# Saida: t_767
#
# Entrada: a
#
# Partes: ['or', 'i20', 't_766', 't_767']
# Operações: or
# Saida: i20
#
# Entradas 1: t_766
# Entradas 2: t_767
#
# Partes: ['not', 't_768', 'x17']
# Operações: not
# Saida: t_768
#
# Entrada: x17
#
# Partes: ['not', 't_769', 'p19']
# Operações: not
# Saida: t_769
#
# Entrada: p19
#
# Partes: ['or', 'i1', 't_768', 't_769']
# Operações: or
# Saida: i1
#
# Entradas 1: t_768
# Entradas 2: t_769
#
# Partes: ['not', 't_770', 'y17']
# Operações: not
# Saida: t_770
#
# Entrada: y17
#
# Partes: ['not', 't_771', 'l19']
# Operações: not
# Saida: t_771
#
# Entrada: l19
#
# Partes: ['or', 'm1', 't_770', 't_771']
# Operações: or
# Saida: m1
#
# Entradas 1: t_770
# Entradas 2: t_771
#
# Partes: ['not', 't_772', 'z17']
# Operações: not
# Saida: t_772
#
# Entrada: z17
#
# Partes: ['not', 't_773', 'h19']
# Operações: not
# Saida: t_773
#
# Entrada: h19
#
# Partes: ['or', 'q1', 't_772', 't_773']
# Operações: or
# Saida: q1
#
# Entradas 1: t_772
# Entradas 2: t_773
#
# Partes: ['not', 't_774', 'a18']
# Operações: not
# Saida: t_774
#
# Entrada: a18
#
# Partes: ['not', 't_775', 'd19']
# Operações: not
# Saida: t_775
#
# Entrada: d19
#
# Partes: ['or', 'u1', 't_774', 't_775']
# Operações: or
# Saida: u1
#
# Entradas 1: t_774
# Entradas 2: t_775
#
# Partes: ['not', 't_776', 'b18']
# Operações: not
# Saida: t_776
#
# Entrada: b18
#
# Partes: ['not', 't_777', 'q19']
# Operações: not
# Saida: t_777
#
# Entrada: q19
#
# Partes: ['or', 'h1', 't_776', 't_777']
# Operações: or
# Saida: h1
#
# Entradas 1: t_776
# Entradas 2: t_777
#
# Partes: ['not', 't_778', 'c18']
# Operações: not
# Saida: t_778
#
# Entrada: c18
#
# Partes: ['not', 't_779', 'm19']
# Operações: not
# Saida: t_779
#
# Entrada: m19
#
# Partes: ['or', 'l1', 't_778', 't_779']
# Operações: or
# Saida: l1
#
# Entradas 1: t_778
# Entradas 2: t_779
#
# Partes: ['not', 't_780', 'd18']
# Operações: not
# Saida: t_780
#
# Entrada: d18
#
# Partes: ['not', 't_781', 'i19']
# Operações: not
# Saida: t_781
#
# Entrada: i19
#
# Partes: ['or', 'p1', 't_780', 't_781']
# Operações: or
# Saida: p1
#
# Entradas 1: t_780
# Entradas 2: t_781
#
# Partes: ['not', 't_782', 'e18']
# Operações: not
# Saida: t_782
#
# Entrada: e18
#
# Partes: ['not', 't_783', 'e19']
# Operações: not
# Saida: t_783
#
# Entrada: e19
#
# Partes: ['or', 't1', 't_782', 't_783']
# Operações: or
# Saida: t1
#
# Entradas 1: t_782
# Entradas 2: t_783
#
# Partes: ['not', 't_784', 'f18']
# Operações: not
# Saida: t_784
#
# Entrada: f18
#
# Partes: ['not', 't_785', 'r19']
# Operações: not
# Saida: t_785
#
# Entrada: r19
#
# Partes: ['or', 'g1', 't_784', 't_785']
# Operações: or
# Saida: g1
#
# Entradas 1: t_784
# Entradas 2: t_785
#
# Partes: ['not', 't_786', 'g18']
# Operações: not
# Saida: t_786
#
# Entrada: g18
#
# Partes: ['not', 't_787', 'n19']
# Operações: not
# Saida: t_787
#
# Entrada: n19
#
# Partes: ['or', 'k1', 't_786', 't_787']
# Operações: or
# Saida: k1
#
# Entradas 1: t_786
# Entradas 2: t_787
#
# Partes: ['not', 't_788', 'h18']
# Operações: not
# Saida: t_788
#
# Entrada: h18
#
# Partes: ['not', 't_789', 'j19']
# Operações: not
# Saida: t_789
#
# Entrada: j19
#
# Partes: ['or', 'o1', 't_788', 't_789']
# Operações: or
# Saida: o1
#
# Entradas 1: t_788
# Entradas 2: t_789
#
# Partes: ['not', 't_790', 'i18']
# Operações: not
# Saida: t_790
#
# Entrada: i18
#
# Partes: ['not', 't_791', 'f19']
# Operações: not
# Saida: t_791
#
# Entrada: f19
#
# Partes: ['or', 's1', 't_790', 't_791']
# Operações: or
# Saida: s1
#
# Entradas 1: t_790
# Entradas 2: t_791
#
# Partes: ['not', 't_792', 'j18']
# Operações: not
# Saida: t_792
#
# Entrada: j18
#
# Partes: ['not', 't_793', 's19']
# Operações: not
# Saida: t_793
#
# Entrada: s19
#
# Partes: ['or', 'f1', 't_792', 't_793']
# Operações: or
# Saida: f1
#
# Entradas 1: t_792
# Entradas 2: t_793
#
# Partes: ['not', 't_794', 'k18']
# Operações: not
# Saida: t_794
#
# Entrada: k18
#
# Partes: ['not', 't_795', 'o19']
# Operações: not
# Saida: t_795
#
# Entrada: o19
#
# Partes: ['or', 'j1', 't_794', 't_795']
# Operações: or
# Saida: j1
#
# Entradas 1: t_794
# Entradas 2: t_795
#
# Partes: ['not', 't_796', 'l18']
# Operações: not
# Saida: t_796
#
# Entrada: l18
#
# Partes: ['not', 't_797', 'k19']
# Operações: not
# Saida: t_797
#
# Entrada: k19
#
# Partes: ['or', 'n1', 't_796', 't_797']
# Operações: or
# Saida: n1
#
# Entradas 1: t_796
# Entradas 2: t_797
#
# Partes: ['not', 't_798', 'm18']
# Operações: not
# Saida: t_798
#
# Entrada: m18
#
# Partes: ['not', 't_799', 'g19']
# Operações: not
# Saida: t_799
#
# Entrada: g19
#
# Partes: ['or', 'r1', 't_798', 't_799']
# Operações: or
# Saida: r1
#
# Entradas 1: t_798
# Entradas 2: t_799
#
# Partes: ['not', 't_800', 'n18']
# Operações: not
# Saida: t_800
#
# Entrada: n18
#
# Partes: ['not', 't_801', 'f20']
# Operações: not
# Saida: t_801
#
# Entrada: f20
#
# Partes: ['or', 's0', 't_800', 't_801']
# Operações: or
# Saida: s0
#
# Entradas 1: t_800
# Entradas 2: t_801
#
# Partes: ['not', 't_802', 'o18']
# Operações: not
# Saida: t_802
#
# Entrada: o18
#
# Partes: ['not', 't_803', 'b20']
# Operações: not
# Saida: t_803
#
# Entrada: b20
#
# Partes: ['or', 'w0', 't_802', 't_803']
# Operações: or
# Saida: w0
#
# Entradas 1: t_802
# Entradas 2: t_803
#
# Partes: ['not', 't_804', 'p18']
# Operações: not
# Saida: t_804
#
# Entrada: p18
#
# Partes: ['not', 't_805', 'x19']
# Operações: not
# Saida: t_805
#
# Entrada: x19
#
# Partes: ['or', 'a1', 't_804', 't_805']
# Operações: or
# Saida: a1
#
# Entradas 1: t_804
# Entradas 2: t_805
#
# Partes: ['not', 't_806', 'q18']
# Operações: not
# Saida: t_806
#
# Entrada: q18
#
# Partes: ['not', 't_807', 't19']
# Operações: not
# Saida: t_807
#
# Entrada: t19
#
# Partes: ['or', 'e1', 't_806', 't_807']
# Operações: or
# Saida: e1
#
# Entradas 1: t_806
# Entradas 2: t_807
#
# Partes: ['not', 't_808', 'r18']
# Operações: not
# Saida: t_808
#
# Entrada: r18
#
# Partes: ['not', 't_809', 'g20']
# Operações: not
# Saida: t_809
#
# Entrada: g20
#
# Partes: ['or', 'r0', 't_808', 't_809']
# Operações: or
# Saida: r0
#
# Entradas 1: t_808
# Entradas 2: t_809
#
# Partes: ['not', 't_810', 's18']
# Operações: not
# Saida: t_810
#
# Entrada: s18
#
# Partes: ['not', 't_811', 'c20']
# Operações: not
# Saida: t_811
#
# Entrada: c20
#
# Partes: ['or', 'v0', 't_810', 't_811']
# Operações: or
# Saida: v0
#
# Entradas 1: t_810
# Entradas 2: t_811
#
# Partes: ['not', 't_812', 't18']
# Operações: not
# Saida: t_812
#
# Entrada: t18
#
# Partes: ['not', 't_813', 'y19']
# Operações: not
# Saida: t_813
#
# Entrada: y19
#
# Partes: ['or', 'z0', 't_812', 't_813']
# Operações: or
# Saida: z0
#
# Entradas 1: t_812
# Entradas 2: t_813
#
# Partes: ['not', 't_814', 'u18']
# Operações: not
# Saida: t_814
#
# Entrada: u18
#
# Partes: ['not', 't_815', 'u19']
# Operações: not
# Saida: t_815
#
# Entrada: u19
#
# Partes: ['or', 'd1', 't_814', 't_815']
# Operações: or
# Saida: d1
#
# Entradas 1: t_814
# Entradas 2: t_815
#
# Partes: ['not', 't_816', 'v18']
# Operações: not
# Saida: t_816
#
# Entrada: v18
#
# Partes: ['not', 't_817', 'h20']
# Operações: not
# Saida: t_817
#
# Entrada: h20
#
# Partes: ['or', 'q0', 't_816', 't_817']
# Operações: or
# Saida: q0
#
# Entradas 1: t_816
# Entradas 2: t_817
#
# Partes: ['not', 't_818', 'w18']
# Operações: not
# Saida: t_818
#
# Entrada: w18
#
# Partes: ['not', 't_819', 'd20']
# Operações: not
# Saida: t_819
#
# Entrada: d20
#
# Partes: ['or', 'u0', 't_818', 't_819']
# Operações: or
# Saida: u0
#
# Entradas 1: t_818
# Entradas 2: t_819
#
# Partes: ['not', 't_820', 'x18']
# Operações: not
# Saida: t_820
#
# Entrada: x18
#
# Partes: ['not', 't_821', 'z19']
# Operações: not
# Saida: t_821
#
# Entrada: z19
#
# Partes: ['or', 'y0', 't_820', 't_821']
# Operações: or
# Saida: y0
#
# Entradas 1: t_820
# Entradas 2: t_821
#
# Partes: ['not', 't_822', 'y18']
# Operações: not
# Saida: t_822
#
# Entrada: y18
#
# Partes: ['not', 't_823', 'v19']
# Operações: not
# Saida: t_823
#
# Entrada: v19
#
# Partes: ['or', 'c1', 't_822', 't_823']
# Operações: or
# Saida: c1
#
# Entradas 1: t_822
# Entradas 2: t_823
#
# Partes: ['not', 't_824', 'z18']
# Operações: not
# Saida: t_824
#
# Entrada: z18
#
# Partes: ['not', 't_825', 'i20']
# Operações: not
# Saida: t_825
#
# Entrada: i20
#
# Partes: ['or', 'p0', 't_824', 't_825']
# Operações: or
# Saida: p0
#
# Entradas 1: t_824
# Entradas 2: t_825
#
# Partes: ['not', 't_826', 'a19']
# Operações: not
# Saida: t_826
#
# Entrada: a19
#
# Partes: ['not', 't_827', 'e20']
# Operações: not
# Saida: t_827
#
# Entrada: e20
#
# Partes: ['or', 't0', 't_826', 't_827']
# Operações: or
# Saida: t0
#
# Entradas 1: t_826
# Entradas 2: t_827
#
# Partes: ['not', 't_828', 'b19']
# Operações: not
# Saida: t_828
#
# Entrada: b19
#
# Partes: ['not', 't_829', 'a20']
# Operações: not
# Saida: t_829
#
# Entrada: a20
#
# Partes: ['or', 'x0', 't_828', 't_829']
# Operações: or
# Saida: x0
#
# Entradas 1: t_828
# Entradas 2: t_829
#
# Partes: ['not', 't_830', 'c19']
# Operações: not
# Saida: t_830
#
# Entrada: c19
#
# Partes: ['not', 't_831', 'w19']
# Operações: not
# Saida: t_831
#
# Entrada: w19
#
# Partes: ['or', 'b1', 't_830', 't_831']
# Operações: or
# Saida: b1
#
# Entradas 1: t_830
# Entradas 2: t_831

# %%
# 2° Parte: adicionando a porta lógica a BN

def add_port_logic (bn, operacao, output, inputs):
    """
    Adiciona a porta lógica a rede bayseana 

    parametros->
    bn: rede bayseana
    operacao: porta lógica (or, not, and)
    output: variavel de saida
    input: variaveis de entrada (lista)
    """

    operacao = operacao.lower() # evitando erro por maiusculo

    # criação das variaveis de entrada

    for inp in inputs: 
        if inp not in bn.names(): # evita de criar variaveis já criadas na rede bayseana
            variavel = gum.LabelizedVariable(inp, inp, 2)
            # variavel = bn.add(gum.LabelizedVariable(inp,inp,2))
            bn.add(variavel)
            # criação da cpt
            bn.cpt(inp).fillWith([0.5,0.5])


        # criar variavel da saida
    if output not in bn.names():
        variavel_output = gum.LabelizedVariable(output, output, 2)
        bn.add(variavel_output)


    # add arcos da entrada para a saida
    for inp in inputs:
        bn.addArc(inp, output)

    # Definir a CPT com base na operação lógica
    if operacao == "not":
        if len(inputs) != 1:
            raise ValueError("A operação 'not' requer exatamente 1 entrada.")

        inp = inputs[0]
        # Porta NOT: Y = NOT X
        # Definindo P(Y=1 | X=0) = 1.0 e P(Y=0 | X=0) = 0.0
        # Definindo P(Y=1 | X=1) = 0.0 e P(Y=0 | X=1) = 1.0
        bn.cpt(output)[{inp: 0}] = [0.0, 1.0]  # Y=0, Y=1
        bn.cpt(output)[{inp: 1}] = [1.0, 0.0]  # Y=0, Y=1
        
    elif operacao == "or":
        if len(inputs) != 2:
            raise ValueError("Erro brabo")
        # Porta OR: Y = X1 OR X2 OR ...
        #                                              [0, 1] -> bits
        bn.cpt(output)[{inputs[0]: 0, inputs[1]: 0}] = [1.0, 0.0]  # P(Y=0|r=0,s=0) = 1.0, P(Y=1|r=0,s=0) = 0.0
        bn.cpt(output)[{inputs[0]: 0, inputs[1]: 1}] = [0.0, 1.0]  # P(Y=0|r=0,s=1) = 0.0, P(Y=1|r=0,s=1) = 1.0
        bn.cpt(output)[{inputs[0]: 1, inputs[1]: 0}] = [0.0, 1.0]  # P(Y=0|r=1,s=0) = 0.0, P(Y=1|r=1,s=0) = 1.0
        bn.cpt(output)[{inputs[0]: 1, inputs[1]: 1}] = [0.0, 1.0]  # P(Y=0|r=1,s=1) = 0.0, P(Y=1|r=1,s=1) = 1.0

    elif operacao == "and":
        # Porta AND: Y = X1 AND X2 AND ...
        bn.cpt(output)[{inputs[0]: 0, inputs[1]: 0}] = [1.0, 0.0]  # P(Y=0|r=0,s=0) = 1.0, P(Y=1|r=0,s=0) = 0.0
        bn.cpt(output)[{inputs[0]: 0, inputs[1]: 1}] = [1.0, 0.0]  # P(Y=0|r=0,s=1) = 0.0, P(Y=1|r=0,s=1) = 0.0
        bn.cpt(output)[{inputs[0]: 1, inputs[1]: 0}] = [1.0, 0.0]  # P(Y=0|r=1,s=0) = 0.0, P(Y=1|r=1,s=0) = 0.0
        bn.cpt(output)[{inputs[0]: 1, inputs[1]: 1}] = [0.0, 1.0]  # P(Y=0|r=1,s=1) = 0.0, P(Y=1|r=1,s=1) = 1.0

    else:
        raise ValueError(f"Operação lógica '{operacao}' não suportada.")

# %%
# teste com circuito pequeno de uma porta
bn = gum.BayesNet('test')
input = ['s0', 's1']
output = 'r0'
operacao = 'and'
add_port_logic(bn,operacao=operacao, output=output, inputs=input)

gnb.sideBySide(bn.cpt(output), gnb.getBN(bn, size='1.9!'), captions=[f'Porta {operacao}','Rede Bayseana'])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='2'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>r0</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>s1</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>s0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.00</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.00</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.00</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.00</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.00</td><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.00</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#ff7f64;text-align:right;padding: 3px;'>0.00</td><td style='color:black;background-color:#7fff64;text-align:right;padding: 3px;'>1.00</td></tr>
# </table><br><small><i>Porta and</i></small></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="137pt" height="119pt" viewBox="0.00 0.00 137.00 118.60">
# <g id="graph0" class="graph" transform="scale(0.98 0.98) rotate(0) translate(4 112)">
# <title>G</title>
# <!-- r0 -->
# <g id="node1" class="node">
# <title>r0</title>
# <g id="a_node1"><a xlink:title="(2) r0">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="63" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="63" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">r0</text>
# </a>
# </g>
# </g>
# <!-- s0 -->
# <g id="node2" class="node">
# <title>s0</title>
# <g id="a_node2"><a xlink:title="(0) s0">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">s0</text>
# </a>
# </g>
# </g>
# <!-- s0&#45;&gt;r0 -->
# <g id="edge1" class="edge">
# <title>s0-&gt;r0</title>
# <g id="a_edge1"><a xlink:title="0 → 2">
# <path fill="none" stroke="#4a4a4a" d="M35.35,-72.76C39.71,-64.28 45.15,-53.71 50.04,-44.2"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="53.23,-45.64 54.7,-35.15 47.01,-42.44 53.23,-45.64"/>
# </a>
# </g>
# </g>
# <!-- s1 -->
# <g id="node3" class="node">
# <title>s1</title>
# <g id="a_node3"><a xlink:title="(1) s1">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="99" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">s1</text>
# </a>
# </g>
# </g>
# <!-- s1&#45;&gt;r0 -->
# <g id="edge2" class="edge">
# <title>s1-&gt;r0</title>
# <g id="a_edge2"><a xlink:title="1 → 2">
# <path fill="none" stroke="#4a4a4a" d="M90.65,-72.76C86.29,-64.28 80.85,-53.71 75.96,-44.2"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="78.99,-42.44 71.3,-35.15 72.77,-45.64 78.99,-42.44"/>
# </a>
# </g>
# </g>
# </g>
# </svg><br><small><i>Rede Bayseana</i></small></div></td></tr></table>

# %%
# 3° Parte: criando com base no txt

def build_bn(path_txt):
    """
    Constrói uma rede bayesiana a partir de definições de portas lógicas em texto.

    Parâmetros:
    - gate_definitions_text: String contendo as definições das portas lógicas, uma por linha.

    Retorna:
    - bn: Instância da rede bayesiana construída (gum.BayesNet).
    """
    bn = gum.BayesNet('Circuito_Combinacional')

    # Processar cada linha de definição de porta lógica
    with open(path_txt, 'r') as f:

        for linha in f: 
            linha = linha.strip()
            if not linha:
                continue 

            partes = linha.split()
            operacao = partes[0] # porta lógica
            saida = partes[1] # output
            entradas = partes[2:] # input
            add_port_logic(bn, operacao=operacao, output=saida, inputs=entradas)

    return bn

# %%
# teste com meio somador
write_to_file(read_verilog('verilog/somador2bits.v'), 'data/somador2bits.txt')
bn2 = build_bn('data/somador2bits.txt')
gum.saveBN(bn,"data/somador2bits.xdsl")

bn2
# Out:
# (pyAgrum.BayesNet<double>@0x316e8e0) BN{nodes: 13, arcs: 14, domainSize: 8192, dim: 32, mem: 512o}

# %%
bn3 = build_bn('verilog/C1355.txt')
gum.saveBN(bn3, 'data/C1355.xdsl')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_185661/783028894.py in ?()
# ----> 1 bn3 = build_bn('verilog/C1355.txt')
#       2 gum.saveBN(bn3, 'data/C1355.xdsl')
#
# /tmp/ipykernel_185661/2653699059.py in ?(path_txt)
#      23             partes = linha.split()
#      24             operacao = partes[0] # porta lógica
#      25             saida = partes[1] # output
#      26             entradas = partes[2:] # input
# ---> 27             add_port_logic(bn, operacao=operacao, output=saida, inputs=entradas)
#      28
#      29     return bn
#
# /tmp/ipykernel_185661/361381455.py in ?(bn, operacao, output, inputs)
#      57         bn.cpt(output)[{inputs[0]: 1, inputs[1]: 1}] = [0.0, 1.0]  # P(Y=0|r=1,s=1) = 0.0, P(Y=1|r=1,s=1) = 1.0
#      58
#      59     elif operacao == "and":
#      60         # Porta AND: Y = X1 AND X2 AND ...
# ---> 61         bn.cpt(output)[{inputs[0]: 0, inputs[1]: 0}] = [1.0, 0.0]  # P(Y=0|r=0,s=0) = 1.0, P(Y=1|r=0,s=0) = 0.0
#      62         bn.cpt(output)[{inputs[0]: 0, inputs[1]: 1}] = [1.0, 0.0]  # P(Y=0|r=0,s=1) = 0.0, P(Y=1|r=0,s=1) = 0.0
#      63         bn.cpt(output)[{inputs[0]: 1, inputs[1]: 0}] = [1.0, 0.0]  # P(Y=0|r=1,s=0) = 0.0, P(Y=1|r=1,s=0) = 0.0
#      64         bn.cpt(output)[{inputs[0]: 1, inputs[1]: 1}] = [0.0, 1.0]  # P(Y=0|r=1,s=1) = 0.0, P(Y=1|r=1,s=1) = 1.0
#
# ~/Documentos/IC/.venv/lib/python3.8/site-packages/pyAgrum/pyAgrum.py in ?(self, id, value)
#    9924                 raise ArgumentError(f"{value} is not a correct value for a potential.")
#    9925
#    9926         shape=tuple([loopvars.variable(i-1).domainSize() for i in range(loopvars.nbrDim(),0,-1)])
#    9927         if value.shape!=shape:
# -> 9928           raise IndexError("Shape of '"+str(value)+"' is not '"+str(shape)+"'")
#    9929
#    9930         names = [loopvars.variable(i - 1).name() for i in range(loopvars.nbrDim(), 0, -1)]
#    9931         while not inst.end():
#
# IndexError: Shape of '[1. 0.]' is not '(2, 2, 2)'
